# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# ### 1.0 Первичная обработка данных

# %%
# чтение данных и их адаптация для дальнейшей работы

import pandas as pd

courses = pd.read_csv("Data\courses.csv")
course_contents = pd.read_csv("Data\course_contents.csv")
progress_phases = pd.read_csv("Data\progress_phases.csv")
progresses = pd.read_csv("Data\progresses.csv")
students = pd.read_csv("Data\students.csv")


progresses.rename(columns = {'id':'progress_id'}, inplace = True)
courses.rename(columns = {'id':'course_id'}, inplace = True)
N = len(courses)

# %%
# создание словаря {id_курса:название_курса}

id_title = {courses.iloc[i].course_id:courses.iloc[i].title
            for i in range(N)}
id_title
# Out:
# {'943306102e5b067d08a29094f37b8193': 'Java-разработчик c нуля',
#  '17013cd19d25cb3f28dc1b2683721bb9': 'Веб-дизайн Базовый',
#  'ac634845fb0350d0e9d49078aaa4b68f': 'Excel Базовый',
#  '0770b1b039964228294f1f34b29fc2c1': 'Руководитель digital-проектов',
#  'abce125a877c2196a3bc7bfbc11b5fc5': 'Веб-вёрстка для начинающих 2.0',
#  'e9bb9205eeed307ee7cbaa08bfd166c3': 'JavaScript с нуля',
#  '04ba6d0b40670c43a209141fa01fa784': 'Анимация интерфейсов',
#  'c9fcb746d51e41bc5a217002d081454b': 'Веб-дизайн PRO 2.0',
#  'dad6f6ffc086caa89e2f40c28a9c7490': 'UX-дизайн',
#  'bf27a4bf4ada4c756451703ea62a914f': 'Интернет-маркетолог от Ingate',
#  'e3a0df907589d56692b5cb561fd90d87': 'Веб-дизайн с нуля 2.0',
#  '480d25ad36878fce09e7aada316ba1a6': 'Веб-разработчик',
#  '842218e7c983795934bbe4533c0888c8': 'SMM-маркетолог от А до Я',
#  'ccbab00e99b27f83369d6cc89d914ad6': 'PHP-разработчик с 0 до PRO. Часть 1',
#  '6e4837f0a65c68efbfdd0594d6774701': 'Java-разработчик'}

# %%
# создание словаря {название_курса:сфера_курса}; для графиков

course_field = {courses.iloc[i].title : courses.iloc[i].field
                for i in range(N)}
course_field
# Out:
# {'Java-разработчик c нуля': 'Development',
#  'Веб-дизайн Базовый': 'Design',
#  'Excel Базовый': 'Business',
#  'Руководитель digital-проектов': 'Business',
#  'Веб-вёрстка для начинающих 2.0': 'Development',
#  'JavaScript с нуля': 'Development',
#  'Анимация интерфейсов': 'Design',
#  'Веб-дизайн PRO 2.0': 'Design',
#  'UX-дизайн': 'Design',
#  'Интернет-маркетолог от Ingate': 'Marketing',
#  'Веб-дизайн с нуля 2.0': 'Design',
#  'Веб-разработчик': 'Development',
#  'SMM-маркетолог от А до Я': 'Marketing',
#  'PHP-разработчик с 0 до PRO. Часть 1': 'Development',
#  'Java-разработчик': 'Development'}

# %%
# объединение датасета курсов с датасетом их модулей

courses = pd.merge(courses, course_contents)
del courses['Unnamed: 0']
courses.head()
# Out:
#                           course_id                    title        field  \
# 0  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 1  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 2  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 3  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 4  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
#
#    module_number    module_title  lesson_number  \
# 0              1  Вводный модуль              1
# 1              1  Вводный модуль              2
# 2              1  Вводный модуль              3
# 3              1  Вводный модуль              4
# 4              1  Вводный модуль              5
#
#                       lesson_title                          lesson_token  \
# 0           Какие бывают программы  cf394764-8850-4a0a-8d02-03470fe5345c
# 1  Где и для чего применяется Java  b3c2b829-aa3f-4607-a829-b74b69071b19
# 2     Как выглядит программный код  c25eac6e-b6bb-4de6-957f-f077f07856fc
# 3       Установка среды разработки  0ac58921-5765-40aa-aec9-544f8313e3f6
# 4    Исправляем готовое приложение  b28da8d8-0a6e-40bd-b01d-d529d1ad260d
#
#    is_video  is_homework
# 0      True        False
# 1      True        False
# 2      True        False
# 3      True        False
# 4      True        False

# %%
# объединеие всех датасеов, кроме students

main = pd.merge(progresses, progress_phases)
main = pd.merge(courses, main)
main.head()
# Out:
#                           course_id                    title        field  \
# 0  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 1  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 2  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 3  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 4  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
#
#    module_number    module_title  lesson_number            lesson_title  \
# 0              1  Вводный модуль              1  Какие бывают программы
# 1              1  Вводный модуль              1  Какие бывают программы
# 2              1  Вводный модуль              1  Какие бывают программы
# 3              1  Вводный модуль              1  Какие бывают программы
# 4              1  Вводный модуль              1  Какие бывают программы
#
#                            lesson_token  is_video  is_homework  \
# 0  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 1  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 2  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 3  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 4  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
#
#                         progress_id                        student_id status  \
# 0  45cdf025b87db75e84f93c4ac3ccb5c7  0b4656b84ca60350583f8fbe236dda86   done
# 1  0c56109dde49080e7441e95b22bb73c2  1d874e6b6bdc34559781f65f9f761791   done
# 2  36079c0615d85f3cebfa47542b43ab41  ab7f5c720e3a5e1de00c2cdbef19fbf0   done
# 3  37384cbeb141835cc61b5fd22abd9200  29ab3f8c52a858bea2d3b9a51c433578   done
# 4  3a79d622c4057c1c029c74e282e43396  72afe01498ba14045467fc32029b650c   done
#
#                       start_date                    finish_date
# 0  2019-03-29 17:02:32.838469+00  2019-04-13 17:32:19.134874+00
# 1  2019-06-13 19:22:19.331201+00  2019-06-13 19:51:21.987534+00
# 2  2019-03-27 06:56:51.138795+00  2019-03-27 06:56:54.834751+00
# 3  2019-05-28 11:09:29.320478+00  2019-05-29 06:47:21.794092+00
# 4  2019-03-24 07:03:03.582679+00  2019-03-24 09:50:32.595199+00

# %% [markdown]
# **Примечание:**<br>
# *Отдельный датасет для возраста студентов не создавал, так как получилось в той же таблице выполнить рассчеты по возрасту (см. далее).*

# %% [markdown]
# ### 1.1 Рассчёт показателей

# %% [markdown]
# ### 1.1.1 Количество курсов в датасете

# %%
print(N)
# Out:
# 15

# %% [markdown]
# ### 1.1.2 Количество модулей на каждом курсе

# %%
directory = 'CreatedData/'

# %%
filename = 'NModulesPerCourse.html'
title_modnum = dict() # cловарь {название_курса:количество_модулей}
mod_p_course = pd.DataFrame(columns = ('Название курса', 'Количество модулей'))
for i in id_title.values():
    title_modnum[i] = len(set(courses[courses.title == i].module_title))
    mod_p_course.loc[len(mod_p_course)] = (i, title_modnum[i])
mod_p_course.to_html(directory + filename, index = False)

# %% [markdown]
# ### 1.1.3 Количество уроков в каждом модуле на каждом курсе

# %%
filename = 'NLessonsPerModule.html'
les_p_mod = pd.DataFrame(columns = ('Название курса', 'Название модуля',
                                   'Количество уроков'))
course_modules = dict() # словарь {название_курса:[кол-во_уроков_помодульно]}
for course in id_title.values():
    course_modules[course] = []
    for module_number in range(1, title_modnum[course] + 1):
        module_title = list(courses[(courses['module_number'] == 
        module_number) & (courses['title'] == 
        course)].module_title)[0]
        
        lessons_number = len(courses[(courses['module_number'] == 
        module_number) & (courses['title'] == 
        course)])
        
        course_modules[course].append(lessons_number)
        les_p_mod.loc[len(les_p_mod)] = (course, module_title, lessons_number)
les_p_mod.set_index(['Название курса', 'Название модуля'], inplace = True)
les_p_mod.to_html(directory + filename)

# %% [markdown]
# ### 1.1.4 Медианное количество уроков в модуле на каждом курсе

# %%
from numpy import median
filename = 'MedLessonsPerModule.html'
course_p_med = pd.DataFrame(columns = ('Название курса', 
                                       'Медианное кол-во уроков в модуле'))
for i in course_modules:
    course_p_med.loc[len(course_p_med)] = (i, median(course_modules[i]))
course_p_med.to_html(directory+filename, index = False)

# %% [markdown]
# ### 1.1.5 Подсчёт характеристик возрастов всех студентов

# %%
# функция для подсчёта возраста студентов из даты рождения

def age(birthday):
    YEAR = 2020
    if (str(birthday) != 'nan'):
        if 12<= (YEAR - int(birthday[:4])) <= 100:
            return YEAR - int(birthday[:4])
    return None

# %%
students['ages'] = students.birthday.apply(age) # создание столбца ages
students.dropna().head()
# Out:
#       id_                                id             city    birthday  ages
# 1    7503  6c3e52be632fc50de9640147e4017dcd           Москва  1979-10-23  41.0
# 7   11070  35a36d90b745992b59085c8d54a072e7       Красноярск  1991-08-15  29.0
# 8   11756  37e8e8179295ae764524223086b0b568           Москва  1987-08-24  33.0
# 11  13568  fb10649db552c5f451bea45ed754d428  Санкт-Петербург  1988-07-16  32.0
# 15  15112  d15a188c90bb4d83957ac14de78fada4  Санкт-Петербург  1991-01-16  29.0

# %%
# отбор валидных значений возраста
correct_ages = list(map(int, students.ages.dropna()))

# %%
from numpy import mean
filename = 'InfoStudAll.html'
char_value = pd.DataFrame(columns = ('Характеристика', 'Значение'))
char_value.loc[0] = ('Максимальный возраст', max(correct_ages))
char_value.loc[1] = ('Минимальный возраст', min(correct_ages))
char_value.loc[2] = ('Средний возраст', round(mean(correct_ages), 2))
char_value.loc[3] = ('Медианный возраст', median(correct_ages))
char_value.to_html(directory + filename, index = False)

# %% [markdown]
# ### 1.1.6 Подсчёт характеристик возрастов студентов каждого курса

# %%
course_studnum = dict() # словарь {название_курса:кол-во_студентов}
filename = 'InfoStudPerCourse.html'
course_stud_info = pd.DataFrame(columns = ('Название курса', 
                                           'Количество студентов',
                                           'Максимальный возраст',
                                           'Минимальный возраст',
                                           'Средний возраст',
                                           'Медианный возраст'))
for course in id_title.values():
    studs = list(set(main[main.title == course ]['student_id']))
    course_studnum[course] = len(studs)
    ages_list = [float(students[students.id == i].ages) for i in studs]
    ages_list = [i for i in ages_list if str(i) != 'nan']
    # Максимальное значение
    max_age = max(ages_list)
    # Минимальное значение
    min_age = min(ages_list)
    # Среднее значение
    mean_age = round(mean(ages_list), 2)
    # Медианное значение
    median_age = median(ages_list)
    course_stud_info.loc[len(course_stud_info)] = (course, len(studs), max_age, min_age, mean_age, median_age)
course_stud_info.to_html(directory + filename, index = False)

# %% [markdown]
# ### 1.2 Горизонтальный bar-chart Student = f(Course)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, subplot = plt.subplots()
x_ticks, y_ticks = list(course_studnum.keys()), list(course_studnum.values())
subplot.barh(x_ticks, y_ticks)
plt.savefig('CreatedData/course_stud.png', bbox_inches = 'tight')

# %% [markdown]
# ### 1.3 Горизонтальный bar-chart Student = f(Course) с оформлением

# %%
# Создаём словарь {сфера:цвет} для дальнейшего окрашивания каждого bar-а
field_color = {'Development': '#1589FF', 
               'Design': '#98FF98', 
               'Business': '#FFA62F', 
               'Marketing': '#F9A7B0'}

# %%
# Создаём словарь, где значения отсортированы по возрастанию
sorted_dict = {j:i for i, j in course_studnum.items()}
sorted_dict = {sorted_dict[i]:i for i in sorted(sorted_dict)}

# %%
# Создаём списки обозначений осей
x_ticks, y_ticks = list(zip(*list(sorted_dict.items())))

# %%
# Создаём список цветов, который соответствует словарю field_color и
# отсортированным значениям x_ticks
color_array = [field_color[course_field[i]] for i in x_ticks]

# %%
# Определяем медиану для дальнейшего построения её линии
med = median(y_ticks)

# %%
from matplotlib.patches import Rectangle # используется для обозначений легенды
fig, subplot = plt.subplots()

# удаление рамки
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.spines['bottom'].set_visible(False)
subplot.spines['left'].set_visible(False)

subplot.barh(x_ticks, y_ticks, color = color_array, alpha = 0.1)

subplot.set_title('Количество студентов на каждом курсе')

# кортеж окрашенных прямоугольников для использования в легенде
rect = tuple(Rectangle((0,0), 10., 5., 
                       color = field_color[i]) for i in field_color)

subplot.legend(rect, tuple(field_color.keys()))

# линия медианы
subplot.vlines(med,-0.4,14.4, color = 'brown')

plt.savefig('CreatedData/course_stud_format.png', bbox_inches = 'tight')

# %% [markdown]
# ### 1.4 Описание полученных данных

# %% [markdown]
# 1. *Количество курсов*: 15

# %% [markdown]
# 2. *Количество модулей на каждом курсе:* <br>
# <table class="dataframe" align="left">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Название курса</th>
#       <th>Количество модулей</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Java-разработчик c нуля</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн Базовый</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <td>Excel Базовый</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>Руководитель digital-проектов</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>JavaScript с нуля</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>Анимация интерфейсов</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <td>UX-дизайн</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <td>Веб-разработчик</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>Java-разработчик</td>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 3. *Количество уроков в каждом модуле на каждом курсе*:<br>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Количество уроков</th>
#     </tr>
#     <tr>
#       <th>Название курса</th>
#       <th>Название модуля</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="9" valign="top">Java-разработчик c нуля</th>
#       <th>Вводный модуль</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Синтаксис языка</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Объекты и классы</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Числа, строки и даты</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>Массивы и коллекции</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Наследование и полиморфизм</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Особенности ООП в Java</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Исключения, отладка, тестирование и логгирование</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>Работа с файлами и сетью</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th rowspan="17" valign="top">Веб-дизайн Базовый</th>
#       <th>Интерфейс. Практика Photoshop</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Цели сайта и цели дизайнера</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Базовые знания о типографике. Практика Photoshop</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Веб-типографика</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Основы работы с графикой. Практика Photoshop</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Графика для сайтов</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Формы и кнопки. Практика Photoshop</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Формы и кнопки: интерактивные элементы</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Универсальные элементы сайтов. Практика Photoshop</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Цвет, атмосфера, тексты и здравый смысл</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Интерактивные элементы. Практика Photoshop</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Интерактивные элементы</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Инфографика. Практика Photoshop</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Инфографика: как сделать сайты интересными</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Подходя к финишной черте. Практика Photoshop</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Финальный день</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Дипломная работа</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="9" valign="top">Excel Базовый</th>
#       <th>Основной функционал Excel</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>Основной функционал Excel (продолжение)</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Формулы и функции Excel. Введение</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Формулы и функции Excel. Продолжаем работать с формулами</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Формулы и функции Excel. Более сложные формулы</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Формулы и функции Excel. Работа с ошибками, проверка данных</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Визуализация данных Excel</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Сводные таблицы Excel</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Экзаменационная работа</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="17" valign="top">Руководитель digital-проектов</th>
#       <th>Экологичный путь менеджера</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Релиз-менеджмент: готовим проекты к запуску</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Требовательность digital-продюсера</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Аналитика. Базовые навыки</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Как пасти котов: правильное делегирование в IT</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Переговорные навыки. Часть 1. Цикл продаж</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Переговорные навыки. Провокации. Работа с возражениями. Часть 2.</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Оценка и декомпозиция digital-проектов</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Управление временем</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Scrum: передовая методология управления современными digital-проектами. Часть 1.</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Scrum. Передовая методология управления digital-проектами. Часть 2.</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Решение факапов. Lean/TOC. Обзор.</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Интеграционные проекты.</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Управление дизайнерами. Разработка дизайна по scrum</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Основы технической грамотности</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Контроль. Риски. Поощрения. Наказания. Обратная связь.</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>БОНУСНЫЙ МОДУЛЬ: Работа с типовыми документами</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">Веб-вёрстка для начинающих 2.0</th>
#       <th>Вводный модуль</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>HTML</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Основы CSS</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Основы JavaScript</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Адаптивность и кроссбраузерность</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Оформление</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Advanced CSS</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Инструменты верстальщика</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="18" valign="top">JavaScript с нуля</th>
#       <th>Знакомство с языком</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Основы</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Функции</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Массивы и объекты</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Замыкания</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Объекты и конструкторы</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Объектно-ориентированное программирование</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Разное</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>JavaScript в браузере; DOM</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Web API</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Клиент и сервер</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>jQuery</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Современный JavaScript; ES 2015</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Сборка проектов</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>React</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Redux</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Бонус</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Экзаменационное задание</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="21" valign="top">Анимация интерфейсов</th>
#       <th>Введение в Motion Design. Тренды, разновидности, применение</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>12 принципов анимации от Walt Disney Studio</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Motion design в интерфейсах</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>After Effects</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Иконки — погружение в мир микроанимации</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Экспорт анимации в код. Плагин Bodymovin</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Прелоадеры</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Material Design</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Звуки в интерфейсе</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Principle (обновлён 06.06.19)</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Webflow — инструмент прототипирования веб-интерфейсов</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>InVision Studio</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Анимация статичной концепции</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Видеобаннеры. Тренд, который заслуживает внимания</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Анимация концепции для презентации клиенту</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Анимация в верстке</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Практика: разбор кейса Уралсиб</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Чистая магия — cоздание продающего шоурила</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Рабочие будни моушн-дизайнера</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Дьявол в деталях</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Дипломная работа</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="17" valign="top">Веб-дизайн PRO 2.0</th>
#       <th>Специализация и личное позиционирование</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Концептуальный дизайн</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль #1</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Введение в UX</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Портреты пользователей и CJM</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Иконки</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Типографика PRO</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль #2</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Readymag</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Продвинутая презентация</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль #3</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Копирайтинг</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Cinema 4D + Blender</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Adobe XD</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Кейс на 1000 лайков</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>План развития дизайнера на 3 года</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Информация о дипломном проекте</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th rowspan="20" valign="top">UX-дизайн</th>
#       <th>Профессия дизайнера в эпоху цифровых перемен</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Основные этапы проекта</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Service design: теория и практика</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>UX-проектирование. Паттерны и психология пользователя</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Эффектный кейс в 20 000 пикселей высоты</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>UX-проектирование. Исследование интерфейсов</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Data driven design: теория и практика</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Дизайн-концепция за 60 минут</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Concept design: творчество в дизайне</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Создание рабочего UI KIT</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Visual design теория и практика</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль. Анимация интерфейсных элементов</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Техника успешной презентации</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Отраслевая специфика</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Разбор кейсов из практики 1С-Битрикс и Битрикс24 — разработка дизайна сайта, продуктов и единой экосистемы интерфейсов</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Разбор кейсов из практики: «Госуслуги» — проектирование и дизайн интерфейсов</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Разбор кейсов из практики: НТВ-плюс — разработка и развитие сайта</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Специализация и карьера</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Экзаменационная тема</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="18" valign="top">Интернет-маркетолог от Ingate</th>
#       <th>Введение в интернет-маркетинг: цели, инструменты, метрики, воронка продаж</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Исследование целевой аудитории: портретирование, анализ сайта, Customer Journey Map  (обновление от 18 марта 2019 г)</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>SEO: больше, чем поисковая выдача (обновление от 30 января 2019 г)</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>Управление репутацией (SERM)</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Медийная реклама и RTB: охват или целевые пользователи?</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Контекстная реклама в Yandex Direct и Google Adwords (обновление от 6 марта 2019 г)</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>Маркетплейсы</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>SMM (обновление от 15 февраля 2019 г)</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Таргетированная реклама в социальных сетях</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Контент-маркетинг: стратегия коммуникации, каналы и инструменты</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Партнерский CPA-маркетинг</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Медиапланирование: разработка комплексной стратегии и ее оценка</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Веб-аналитика: максимум информации об эффективности сайта, источниках трафика и целевой аудитории</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>Юзабилити: разработка эффективного сайта</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Построение маркетинговой структуры и работа с командой</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Email-маркетинг</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>Юридическая сторона рекламы</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Финальное тестирование</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="19" valign="top">Веб-дизайн с нуля 2.0</th>
#       <th>Введение и первый результат</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль #1</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Тренды, подготовка, мудборды</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Работа со стилями. Создание GUI</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Главная страница, первые шаги</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль #2</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Основы работы с графикой</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Бонус-модуль #3</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Декомпозиция</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Навигация и структура</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Интересная подача информации</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Формы и кнопки</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Адаптивность и мобильная версия</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Цвета, настроение. Промо-страница мероприятия.</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Декомпозиция промо-страницы</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3D-элементы в Photoshop</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Презентация для клиента</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Передача проекта в верстку</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Первый кейс на Behance</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th rowspan="20" valign="top">Веб-разработчик</th>
#       <th>О программе</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>HTML. Общая структура HTML-документа</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>HTML. Формы</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Позиционирование при помощи CSS</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>CSS. Знакомство со стилями</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Знакомство с JavaScript</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Javascript – события. Модель обработки событий</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Javascript – события часть 1</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Javascript – события часть 2</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PHP. Место в структуре сайта</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PHP. Пользовательские функции</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PHP. Генерация, работа  с изображениями</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PHP. Работа с файловой системой</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PHP. Взаимодействие  с браузером</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>SQL БД. Концепция, назначение</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Замена текстового файла на Postgresql в качестве бэк-энда</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Материалы для экзамена</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Экзаменационная работа</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Дополнительные модули</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Проверка</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="11" valign="top">SMM-маркетолог от А до Я</th>
#       <th>Постановка задачи и анализ</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Разработка стратегии продвижения в Social Media</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Разработка креативных решений</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Дизайн для не дизайнеров</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Как писать хорошие тексты</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Продвижение в VK, FB, MyTarget</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Запуск проекта и управление командой</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Коммьюнити-менеджмент</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Как работать с клиентом</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Бонусный модуль</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Информация о дипломном проекте</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">PHP-разработчик с 0 до PRO. Часть 1</th>
#       <th>Введение в программирование</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Структура управления данными. Базовые концепции PHP 7</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Протокол HTTP/HTTPS</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Пользовательские функции</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Файлы и каталоги</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Cookie/Session</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>База данных MySQL</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Курсовая работа</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="17" valign="top">Java-разработчик</th>
#       <th>Вводный модуль</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Синтаксис языка</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Объекты и классы</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Числа, строки и даты</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>Массивы и коллекции</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Наследование и полиморфизм</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Тестирование и отладка</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Основы построения GUI</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Внешний вид GUI и рисование</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Работа с файлами и сетью</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Работа с базами данных</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Многопоточность</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Оптимизация кода и приложений</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Основы построения веб-приложений</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Веб-приложения: формы, заголовки и сессии</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Заключительный модуль</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Итоговая тема</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 4. *Медианное количество уроков в модуле на каждом курсе*: <br>
# <table border="1" class="dataframe" align="left">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Название курса</th>
#       <th>Медианное кол-во уроков в модуле</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Java-разработчик c нуля</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн Базовый</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <td>Excel Базовый</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <td>Руководитель digital-проектов</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <td>JavaScript с нуля</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <td>Анимация интерфейсов</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <td>UX-дизайн</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>6.5</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <td>Веб-разработчик</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <td>Java-разработчик</td>
#       <td>7.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 5. *Характеристики возрастов всех студентов*: <br>
# <table border="1" class="dataframe" align="left">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Характеристика</th>
#       <th>Значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Максимальный возраст</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <td>Минимальный возраст</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td>Средний возраст</td>
#       <td>29.7</td>
#     </tr>
#     <tr>
#       <td>Медианный возраст</td>
#       <td>29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 6. *Характеристики возрастов студентов каждого курса (+ количество студентов на курсе)*: <br>
# <table border="1" class="dataframe", align="left">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Название курса</th>
#       <th>Количество студентов</th>
#       <th>Максимальный возраст</th>
#       <th>Минимальный возраст</th>
#       <th>Средний возраст</th>
#       <th>Медианный возраст</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Java-разработчик c нуля</td>
#       <td>581</td>
#       <td>55.0</td>
#       <td>14.0</td>
#       <td>30.14</td>
#       <td>29.0</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн Базовый</td>
#       <td>518</td>
#       <td>51.0</td>
#       <td>16.0</td>
#       <td>29.18</td>
#       <td>28.0</td>
#     </tr>
#     <tr>
#       <td>Excel Базовый</td>
#       <td>782</td>
#       <td>61.0</td>
#       <td>17.0</td>
#       <td>34.24</td>
#       <td>34.0</td>
#     </tr>
#     <tr>
#       <td>Руководитель digital-проектов</td>
#       <td>685</td>
#       <td>55.0</td>
#       <td>19.0</td>
#       <td>32.17</td>
#       <td>32.0</td>
#     </tr>
#     <tr>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>2004</td>
#       <td>60.0</td>
#       <td>14.0</td>
#       <td>29.23</td>
#       <td>28.0</td>
#     </tr>
#     <tr>
#       <td>JavaScript с нуля</td>
#       <td>966</td>
#       <td>60.0</td>
#       <td>14.0</td>
#       <td>29.21</td>
#       <td>28.0</td>
#     </tr>
#     <tr>
#       <td>Анимация интерфейсов</td>
#       <td>598</td>
#       <td>51.0</td>
#       <td>15.0</td>
#       <td>30.23</td>
#       <td>30.0</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1711</td>
#       <td>59.0</td>
#       <td>15.0</td>
#       <td>29.09</td>
#       <td>28.0</td>
#     </tr>
#     <tr>
#       <td>UX-дизайн</td>
#       <td>1151</td>
#       <td>85.0</td>
#       <td>15.0</td>
#       <td>30.81</td>
#       <td>30.0</td>
#     </tr>
#     <tr>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>2168</td>
#       <td>100.0</td>
#       <td>17.0</td>
#       <td>31.88</td>
#       <td>31.0</td>
#     </tr>
#     <tr>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>2014</td>
#       <td>76.0</td>
#       <td>14.0</td>
#       <td>28.81</td>
#       <td>28.0</td>
#     </tr>
#     <tr>
#       <td>Веб-разработчик</td>
#       <td>628</td>
#       <td>51.0</td>
#       <td>14.0</td>
#       <td>28.73</td>
#       <td>28.0</td>
#     </tr>
#     <tr>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>506</td>
#       <td>52.0</td>
#       <td>18.0</td>
#       <td>29.54</td>
#       <td>29.0</td>
#     </tr>
#     <tr>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>854</td>
#       <td>75.0</td>
#       <td>14.0</td>
#       <td>30.12</td>
#       <td>29.0</td>
#     </tr>
#     <tr>
#       <td>Java-разработчик</td>
#       <td>763</td>
#       <td>65.0</td>
#       <td>15.0</td>
#       <td>29.94</td>
#       <td>29.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Анализируя *таблицу 6*, можно заметить некую возрастную особенность для каждой профессии. К примеру, средний возраст студентов выше на курсах, связанных с бизнесом. Далее идут маркетологи, следом дизайнеры. А самые молодые изучают программирование. Это служит доказательством того факта, что чем старше люди становятся, тем тяжелее им браться за трудно-осваиваемые, и, в большинстве случаев, целостные профессии. Им нужнее современные инструменты более прикладного характера (как *Excel базовый*), которые помогают им усовершенствовать уже имеюшиеся навыки.

# %% [markdown]
# 7. *Bar-chart: Количество студентов на каждом курсе*:
# ![title](CreatedData/course_stud_format.png)

# %% [markdown]
# На основе данной диаграммы можно утверждать, что маркетинг всё ещё является самым желаемым направлением на рынке труда. На втором месте профессии, связанные с дизайном (в том числе и *веб-вёрстка*, хоть она и относится больше к разработке). Специалистов по бизнесу гораздо меньше, так как это, в основном, люди старше 30. Разработчики же развиваются на среднем уровне, относительно вышеназванных направлений. Интересно то, что в разработке студентов больше интересуют языки, которые тесно связаны с веб-разработкой (*JavaScript, PHP*).

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# ### 2.1 Рассчёт прироста студентов на каждом курсе

# %%
directory = 'CreatedData2/'

# %%
# список нужных месяцев
months = [str(i) + '-' + (j < 10) * '0' + str(j) for i in range(2016, 2020) for j in range(1, 13)]
months = months[months.index('2016-03'):months.index('2019-09')]
month_growth = pd.DataFrame(columns = ('Месяцы', *list(id_title.values())))
month_growth['Месяцы'] = months[:-1]
month_growth.head()
# Out:
#     Месяцы Java-разработчик c нуля Веб-дизайн Базовый Excel Базовый  \
# 0  2016-03                     NaN                NaN           NaN
# 1  2016-04                     NaN                NaN           NaN
# 2  2016-05                     NaN                NaN           NaN
# 3  2016-06                     NaN                NaN           NaN
# 4  2016-07                     NaN                NaN           NaN
#
#   Руководитель digital-проектов Веб-вёрстка для начинающих 2.0  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   JavaScript с нуля Анимация интерфейсов Веб-дизайн PRO 2.0 UX-дизайн  \
# 0               NaN                  NaN                NaN       NaN
# 1               NaN                  NaN                NaN       NaN
# 2               NaN                  NaN                NaN       NaN
# 3               NaN                  NaN                NaN       NaN
# 4               NaN                  NaN                NaN       NaN
#
#   Интернет-маркетолог от Ingate Веб-дизайн с нуля 2.0 Веб-разработчик  \
# 0                           NaN                   NaN             NaN
# 1                           NaN                   NaN             NaN
# 2                           NaN                   NaN             NaN
# 3                           NaN                   NaN             NaN
# 4                           NaN                   NaN             NaN
#
#   SMM-маркетолог от А до Я PHP-разработчик с 0 до PRO. Часть 1  \
# 0                      NaN                                 NaN
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                                 NaN
# 4                      NaN                                 NaN
#
#   Java-разработчик
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
filename = 'MonthlyGrowth.html'
for course in id_title.values():
    growth = dict() # словарь {'год-месяц':прирост}
    are_homeworks = courses[(courses.title == course) & (courses.is_homework == True)]
    n = len(are_homeworks)
    start_end = ((are_homeworks.iloc[0].module_number,are_homeworks.iloc[0].lesson_number),
                 (are_homeworks.iloc[n - 1].module_number, are_homeworks.iloc[n - 1].lesson_number))
    course_df = main[main.title == course]
    for i, el in enumerate(months[:-1]):
        cur_month = el
        next_month = months[i + 1]
        month_diap = lambda x: (x > cur_month) & (x < next_month)
        # отбор количества начавших и закончивших в этом месяце 
        growth[el] = len(course_df[(course_df.module_number == start_end[0][0]) & (course_df.lesson_number == start_end[0][1])
                           & (month_diap(course_df.start_date))])
    
    month_growth[course] = growth.values()
month_growth.to_html(directory + filename, index = False)
month_growth.tail()
# Out:
#      Месяцы  Java-разработчик c нуля  Веб-дизайн Базовый  Excel Базовый  \
# 36  2019-03                       74                   3             63
# 37  2019-04                      109                   5             46
# 38  2019-05                       74                   1             45
# 39  2019-06                       98                   0             43
# 40  2019-07                       63                   2             28
#
#     Руководитель digital-проектов  Веб-вёрстка для начинающих 2.0  \
# 36                             36                             105
# 37                             17                              91
# 38                             25                              82
# 39                             15                              89
# 40                             20                              72
#
#     JavaScript с нуля  Анимация интерфейсов  Веб-дизайн PRO 2.0  UX-дизайн  \
# 36                 57                    14                  69         39
# 37                 49                    11                  56         20
# 38                 51                    10                  60         26
# 39                 34                    14                  47         48
# 40                 21                     7                  40         18
#
#     Интернет-маркетолог от Ingate  Веб-дизайн с нуля 2.0  Веб-разработчик  \
# 36                            125                    141                9
# 37                            115                    118                0
# 38                            140                    100                9
# 39                            114                     89                3
# 40                             91                     76                4
#
#     SMM-маркетолог от А до Я  PHP-разработчик с 0 до PRO. Часть 1  \
# 36                        42                                   38
# 37                        55                                   32
# 38                        56                                   30
# 39                        67                                   29
# 40                        46                                   15
#
#     Java-разработчик
# 36                74
# 37                 7
# 38                 4
# 39                 4
# 40                 3

# %% [markdown]
# ### 2.2 График ежемесячного прироста студентов на каждом курсе

# %%
from pandas.plotting import register_matplotlib_converters as rmc

rmc()
i = 0
for course in id_title.values():
    i += 1
    filename = 'Course_growth_' + str(i) + '.png'
    fig, subplot = plt.subplots()
    fig.set_size_inches(10, 5)
    subplot.plot(month_growth['Месяцы'], month_growth[course])
    subplot.set_title(f"Ежемесячный прирост студентов курса '{course}'")
    subplot.set_ylabel('Прирост')
    subplot.set_xlabel('Месяцы')
    plt.xticks(month_growth['Месяцы'], rotation = 'vertical')
    plt.savefig(directory + filename, bbox_inches = 'tight')

# %% [markdown]
# ### 2.3 Объединение графиков ежемесячного прироста студентов

# %%
filename = 'All_courses_growth.png'
fig, subplot = plt.subplots()
fig.set_size_inches(10, 5)
for course in id_title.values():
    subplot.plot(month_growth['Месяцы'], month_growth[course])
    subplot.set_title(f"Курс '{course}'")
    plt.xticks(month_growth['Месяцы'], rotation = 'vertical')
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.spines['bottom'].set_visible(False)
subplot.spines['left'].set_visible(False)
subplot.set_ylabel('Прирост')
subplot.set_xlabel('Месяцы')
subplot.set_title('Ежемесячный прирост студентов на всех курсах')
subplot.legend()
plt.savefig(directory + filename, bbox_inches = 'tight')

# %%
filename = 'MonthlyProgress.html'
month_progress = pd.DataFrame(columns = ('Месяцы', *list(id_title.values())))
month_progress['Месяцы'] = months[:-1]
month_progress.head()

# функция для упрощения даты до формата "год-месяц"
cut_month = lambda x: str(x)[:7] 

# создание столбцов с упрощенными датами
main['start_month'] = main['start_date'].apply(cut_month)
main['finish_month'] = main['finish_date'].apply(cut_month)

# отбор значений, соответствующих выполненным домашним работам
cur_frame = main[(main.status == 'done') & (main.is_homework == True)]
for month in range(len(months) - 1):
    month_frame = cur_frame[(months[month] >= main.start_month) & (months[month] <= main.finish_month)]
    for course in id_title.values():
        month_progress[course][month] = len(month_frame[month_frame.title == course])
month_progress.to_html(directory + filename, index = False)
month_progress.tail()
# Out:
# C:\Games\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
#      Месяцы Java-разработчик c нуля Веб-дизайн Базовый Excel Базовый  \
# 36  2019-03                      87                109           340
# 37  2019-04                     477                 98           305
# 38  2019-05                     637                 66           289
# 39  2019-06                     924                 45           246
# 40  2019-07                     616                 24           157
#
#    Руководитель digital-проектов Веб-вёрстка для начинающих 2.0  \
# 36                           348                            532
# 37                           264                            473
# 38                           256                            408
# 39                           172                            348
# 40                           103                            141
#
#    JavaScript с нуля Анимация интерфейсов Веб-дизайн PRO 2.0 UX-дизайн  \
# 36               327                  141                487       303
# 37               315                   92                448       228
# 38               308                   80                477       195
# 39               296                   72                452       200
# 40               101                   24                173        86
#
#    Интернет-маркетолог от Ingate Веб-дизайн с нуля 2.0 Веб-разработчик  \
# 36                           751                  1919              74
# 37                           684                  1716              57
# 38                           609                  1394              51
# 39                           618                  1241              41
# 40                           296                   458              16
#
#    SMM-маркетолог от А до Я PHP-разработчик с 0 до PRO. Часть 1  \
# 36                      134                                 122
# 37                      160                                 144
# 38                      159                                 130
# 39                      182                                  82
# 40                      127                                  29
#
#    Java-разработчик
# 36              469
# 37              261
# 38              171
# 39              102
# 40               36

# %% [markdown]
# ### 2.5 График количества ежемесячного прогресса по каждому курсу

# %%
rmc()
i = 0
for course in id_title.values():
    i += 1
    filename = 'Course_progress_' + str(i) + '.png'
    fig, subplot = plt.subplots()
    fig.set_size_inches(10, 5)
    subplot.plot(month_progress['Месяцы'], month_progress[course])
    subplot.set_title(f"Курс '{course}'")
    subplot.set_ylabel('Количество прогрессов')
    subplot.set_xlabel('Месяцы')
    plt.xticks(month_progress['Месяцы'], rotation = 'vertical')
    plt.savefig(directory + filename, bbox_inches = 'tight')

# %% [markdown]
# ### 2.6 Объединение графиков количества ежемесячного прогресса

# %%
filename = 'All_courses_progress.png'
fig, subplot = plt.subplots()
fig.set_size_inches(10, 5)
for course in id_title.values():
    subplot.plot(month_progress['Месяцы'], month_progress[course])
    plt.xticks(month_progress['Месяцы'], rotation = 'vertical')
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.spines['bottom'].set_visible(False)
subplot.spines['left'].set_visible(False)
subplot.set_ylabel('Количество прогрессов')
subplot.set_xlabel('Месяцы')
subplot.set_title('Количество ежемесячного прогресса на всех курсах')
subplot.legend()
plt.savefig(directory + filename, bbox_inches = 'tight')

# %% [markdown]
# ### 2.7 Аналитический вывод

# %% [markdown]
# <img src="https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData2/All_courses_growth.png" width = "470" align = "left"><img src="https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData2/All_courses_progress.png" width = "470" align = "left">

# %% [markdown]
# Анализируя данные выше, можно увидеть, что массовый старт продаж курсов *SkillBox* начался в январе 2018 года. Скорее всего, именно тогда он начал приобретать известность и продвигать рекламные кампании по привлечению студентов и наборы на профессии (примечателен тот факт, что, по данным сайта <a href = "http://archive.org">archive.org</a> домен *skillbox.ru* находился на стадии продажи до августа 2016 года). Опять же, лидирующие позиции по характеристикам ежемесячного прироста и прогресса занимают:
#
# 1. Веб-дизайн с нуля
# 2. Интернет-маркетолог от Ingate
# 3. Веб-вёрстка для начинающих
#
# Тренды графиков (при определённом приближении), можно сказать, одинаковы в точках возрасатания и убывания. При этом пик прироста и прогресса абсолютного большинства курсов достигается при декабре-январе, в сезон новогодних скидок, распродаж, обширной программе вебинаров и мастер-классов, а также благодаря розыгрышам. Производительность студентов начинает падать ближе к лету, когда у студентов вузов сессионный период, а у остальных - каникулы, отпуск. На саморазвитие остаётся меньше времени.

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# ### 3.1, 3.2 Рассчёт статистических характеристик времени прохождения каждого модуля и построение графиков

# %%
les_p_mod['Минимум'] = None
les_p_mod['Максимум'] = None
les_p_mod['Среднее'] = None
les_p_mod['Медиана'] = None
les_p_mod['standart_deviation_p'] = None #Будет использоваться в метрике успеваемости
les_p_mod['standart_deviation_n'] = None
les_p_mod['start_token'] = None
les_p_mod['finish_token'] = None
les_p_mod.reset_index(inplace = True)
les_p_mod.head()
# Out:
#             Название курса       Название модуля Количество уроков Минимум  \
# 0  Java-разработчик c нуля        Вводный модуль                 7    None
# 1  Java-разработчик c нуля       Синтаксис языка                 6    None
# 2  Java-разработчик c нуля      Объекты и классы                10    None
# 3  Java-разработчик c нуля  Числа, строки и даты                27    None
# 4  Java-разработчик c нуля   Массивы и коллекции                13    None
#
#   Максимум Среднее Медиана standart_deviation_p standart_deviation_n  \
# 0     None    None    None                 None                 None
# 1     None    None    None                 None                 None
# 2     None    None    None                 None                 None
# 3     None    None    None                 None                 None
# 4     None    None    None                 None                 None
#
#   start_token finish_token
# 0        None         None
# 1        None         None
# 2        None         None
# 3        None         None
# 4        None         None

# %%
from math import sqrt
def std(args):
    mean = np.mean(args)
    args1 = list(args >= mean)
    args2 = list(args < mean)
    stdp = sqrt(sum(list(map(lambda x: (x - mean)**2, args1)))/(len(args1) - 1))
    stdn = sqrt(sum(list(map(lambda x: (x - mean)**2, args2)))/(len(args2) - 1))
    return [stdp, stdn]

# %%
sorted(list(set(courses[(courses.title == 'Анимация интерфейсов') & (courses.is_homework == True)].module_number)))
# Out:
# [1, 2, 3, 4, 5, 7, 8, 10, 11, 12, 13, 14, 15, 18, 21]

# %%
import numpy as np
from datetime import datetime
directory = 'CreatedData3/'
to_date = lambda s: datetime.strptime(s[:19], "%Y-%m-%d %H:%M:%S")
day = lambda date: int(int(str(date).split()[0])/(24*3600*(10**9)))
i = 0
print('Модули, выполнение которых еще не завершено:\n')
for course in id_title.values():
    for module in list(les_p_mod[les_p_mod['Название курса'] == course]['Название модуля']):
        hws = list(courses[(courses.module_title == module) &
                           (courses.title == course) &
                           (courses.is_homework == True)].lesson_token)
        if len(hws) == 1:
            hwdf = main[(main.lesson_token == hws[0]) &
                        (main.status == 'done')]
            start_date = (hwdf.start_date).apply(to_date)
            finish_date = (hwdf.finish_date).apply(to_date)
            les_p_mod.iloc[i, 9], les_p_mod.iloc[i, 10] = hws[0], hws[0]
            delta = list(map(day,(list(np.array(finish_date) - np.array(start_date)))))
            delta = np.array(delta)
            delta = delta[delta >= 0]
            try:
                les_p_mod.iloc[i, 3] = min(delta)
                les_p_mod.iloc[i, 4] = max(delta)
                les_p_mod.iloc[i, 5] = np.mean(delta)
                les_p_mod.iloc[i, 6] = np.median(delta)
                les_p_mod.iloc[i, 7], les_p_mod.iloc[i, 8] = std(delta)
            except:
                print(course, module, sep = ':')
        elif len(hws) > 1:
            hwdff = main[(main.lesson_token == hws[-1]) &
                        (main.status == 'done')]
            hwdfs = main[(main.lesson_token == hws[0]) &
                        (main.status == 'done')]
            stud_del = list(set(hwdfs.student_id) - (set(hwdfs.student_id) & set(hwdff.student_id)))
            for j in stud_del:
                hwdfs = hwdfs[hwdfs.student_id != j]
            stud_del = list(set(hwdff.student_id) - (set(hwdfs.student_id) & set(hwdff.student_id)))
            for j in stud_del:
                hwdff = hwdff[hwdff.student_id != j]
            hwdfs.sort_values(by = ['student_id'])
            hwdff.sort_values(by = ['student_id'])
            start_date = (hwdfs.start_date).apply(to_date)
            finish_date = (hwdff.finish_date).apply(to_date)
            les_p_mod.iloc[i, 9], les_p_mod.iloc[i, 10] = hws[0], hws[-1]
            delta = list(map(day,(list(np.array(finish_date) - np.array(start_date)))))
            delta = np.array(delta)
            delta = delta[delta >= 0]
            try:
                les_p_mod.iloc[i, 3] = min(delta)
                les_p_mod.iloc[i, 4] = max(delta)
                les_p_mod.iloc[i, 5] = np.mean(delta)
                les_p_mod.iloc[i, 6] = np.median(delta)
                les_p_mod.iloc[i, 7], les_p_mod.iloc[i, 8] = std(delta)
            except:
                print(course, module, sep = ':')
        i += 1
    filename = f'MedianModule_{course}.png'
    fig, subplot = plt.subplots()
    cur_df = les_p_mod[les_p_mod['Название курса'] == course].dropna()
    mod_nums = int(mod_p_course[mod_p_course['Название курса'] == course]['Количество модулей'])
    subplot.plot(list(map(str, list(cur_df['Название модуля']))),
                  cur_df['Медиана'])
    subplot.set_ylabel('Количество дней выполнения')
    subplot.set_title(f'Медианы прогрессов модулей курса "{course}"')
    plt.xticks(cur_df['Название модуля'], rotation = 'vertical')
    plt.savefig(directory + filename, bbox_inches = 'tight')
# Out:
# Модули, выполнение которых еще не завершено:
#
# Анимация интерфейсов:InVision Studio

# %%
les_p_mod.dropna(inplace = True)

# %%
course_legend = pd.DataFrame({'Курс':list(courses.title), 
                        'Номер модуля':list(courses.module_number),
                        'Модуль':list(courses.module_title)})
course_legend.drop_duplicates(inplace = True)

# %%
course_legend.reset_index(inplace = True)
del course_legend['index']
course_legend.head(10)
# Out:
#                       Курс  Номер модуля  \
# 0  Java-разработчик c нуля             1
# 1  Java-разработчик c нуля             2
# 2  Java-разработчик c нуля             3
# 3  Java-разработчик c нуля             4
# 4  Java-разработчик c нуля             5
# 5  Java-разработчик c нуля             6
# 6  Java-разработчик c нуля             7
# 7  Java-разработчик c нуля             8
# 8  Java-разработчик c нуля             9
# 9       Веб-дизайн Базовый             1
#
#                                              Модуль
# 0                                    Вводный модуль
# 1                                   Синтаксис языка
# 2                                  Объекты и классы
# 3                              Числа, строки и даты
# 4                               Массивы и коллекции
# 5                        Наследование и полиморфизм
# 6                            Особенности ООП в Java
# 7  Исключения, отладка, тестирование и логгирование
# 8                          Работа с файлами и сетью
# 9                     Интерфейс. Практика Photoshop

# %%
course_legend[course_legend['Курс'] == 'Веб-разработчик']
# Out:
#                 Курс  Номер модуля  \
# 173  Веб-разработчик             1
# 174  Веб-разработчик             2
# 175  Веб-разработчик             3
# 176  Веб-разработчик             4
# 177  Веб-разработчик             5
# 178  Веб-разработчик             6
# 179  Веб-разработчик             7
# 180  Веб-разработчик             8
# 181  Веб-разработчик             9
# 182  Веб-разработчик            10
# 183  Веб-разработчик            11
# 184  Веб-разработчик            12
# 185  Веб-разработчик            13
# 186  Веб-разработчик            14
# 187  Веб-разработчик            15
# 188  Веб-разработчик            16
# 189  Веб-разработчик            17
# 190  Веб-разработчик            18
# 191  Веб-разработчик            19
# 192  Веб-разработчик            20
#
#                                                 Модуль
# 173                                        О программе
# 174               HTML. Общая структура HTML-документа
# 175                                        HTML. Формы
# 176                    Позиционирование при помощи CSS
# 177                         CSS. Знакомство со стилями
# 178                            Знакомство с JavaScript
# 179     Javascript – события. Модель обработки событий
# 180                      Javascript – события часть 1
# 181                       Javascript – события часть 2
# 182                       PHP. Место в структуре сайта
# 183                      PHP. Пользовательские функции
# 184            PHP. Генерация, работа  с изображениями
# 185                    PHP. Работа с файловой системой
# 186                   PHP. Взаимодействие  с браузером
# 187                      SQL БД. Концепция, назначение
# 188  Замена текстового файла на Postgresql в качест...
# 189                             Материалы для экзамена
# 190                            Экзаменационная работа
# 191                              Дополнительные модули
# 192                                           Проверка

# %% [markdown]
# ### 3.3, 3.4 Рассчёт сезонности выполнения домашних заданий и построение графика

# %%
from copy import deepcopy

just_month = lambda x: x[5:7]
season_progress = deepcopy(month_growth[(month_growth['Месяцы'] > '2018') & (month_growth['Месяцы'] < '2019')])
season_progress['Месяцы'] = season_progress['Месяцы'].apply(just_month)
season_progress.set_index(['Месяцы'], inplace = True)
main['month'] = main.start_date.apply(just_month)

# %%
# для перевода в тип datetime
to_date = lambda s: datetime.strptime(s[:19], "%Y-%m-%d %H:%M:%S")

# для подсчёта дней из типа данных numpy.datetime
day = lambda date: int(int(str(date).split()[0])/(24*3600*(10**9)))

fig, subplot = plt.subplots()
fig.set_size_inches(14, 7.5)
main_done = main[(main.status == 'done') & (main.is_homework == True)]
for course in id_title.values():
    course_df = main_done[(main_done.title == course)]
    for month in list(season_progress.index):
        month_df = course_df[course_df.month == month]
        if len(month_df) != 0:
            st_arr = np.array(month_df.start_date.apply(to_date))
            fin_arr = np.array(month_df.finish_date.apply(to_date))
            delta = list(map(day,(list(np.array(fin_arr) - np.array(st_arr)))))
            med = np.median(list(map(day,(list(np.array(fin_arr) - np.array(st_arr))))))
            season_progress.loc[month, course] = med
        else:
            season_progress.loc[month, course] = None
    subplot.plot(season_progress.index, season_progress[course])
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.spines['bottom'].set_visible(False)
subplot.spines['left'].set_visible(False)
subplot.set_ylabel('Медианное количество дней выполнения ДЗ')
subplot.set_xlabel('Месяцы')
subplot.set_title('Сезонность выполнения ДЗ на каждом курсе')
subplot.legend(loc = 'upper left')
plt.savefig('CreatedData3/SeasonHW.png', bbox_inches = 'tight')
season_progress
# Out:
#         Java-разработчик c нуля  Веб-дизайн Базовый  Excel Базовый  \
# Месяцы
# 01                          NaN                 8.0            2.0
# 02                          NaN                 0.0            2.0
# 03                          6.0                12.0            2.0
# 04                          3.0                 8.0            1.0
# 05                          3.0                 6.0            2.0
# 06                          2.0                 7.0            1.0
# 07                          1.0                 7.0            1.0
# 08                          NaN                12.0            3.0
# 09                          NaN                13.0            1.5
# 10                          NaN                18.0            2.0
# 11                          NaN                 7.5            2.0
# 12                          NaN                18.0            4.0
#
#         Руководитель digital-проектов  Веб-вёрстка для начинающих 2.0  \
# Месяцы
# 01                                5.0                             9.0
# 02                                1.0                             8.5
# 03                                6.0                             8.0
# 04                                6.0                             9.0
# 05                                6.0                             8.0
# 06                                6.0                             5.0
# 07                                6.0                             3.0
# 08                               13.0                             7.0
# 09                               10.0                            10.0
# 10                                4.0                            11.0
# 11                                5.5                             9.0
# 12                                7.0                             8.0
#
#         JavaScript с нуля  Анимация интерфейсов  Веб-дизайн PRO 2.0  \
# Месяцы
# 01                    6.0                   6.0                10.0
# 02                    5.0                   2.5                 8.0
# 03                    5.5                   7.0                 7.0
# 04                    4.0                   5.0                 6.5
# 05                    5.0                   6.0                 5.0
# 06                    5.0                   4.0                 4.0
# 07                    5.0                   5.0                 8.0
# 08                    7.0                   3.0                31.0
# 09                   11.0                   7.0                27.0
# 10                   12.0                   5.0                14.5
# 11                    8.0                   8.0                10.0
# 12                    8.0                  11.0                10.0
#
#         UX-дизайн  Интернет-маркетолог от Ingate  Веб-дизайн с нуля 2.0  \
# Месяцы
# 01            9.0                            5.0                    5.0
# 02            4.0                            3.5                    6.0
# 03            9.0                            6.0                    4.0
# 04            8.0                            7.0                    4.0
# 05            8.0                            7.0                    4.0
# 06            6.0                            5.0                    3.0
# 07            6.0                            4.0                    3.0
# 08            9.5                            7.0                    7.0
# 09           11.0                            4.0                    8.0
# 10           13.0                            7.0                    7.0
# 11           10.0                            6.0                    7.0
# 12           10.0                            5.0                    7.0
#
#         Веб-разработчик  SMM-маркетолог от А до Я  \
# Месяцы
# 01                  6.0                      12.0
# 02                  3.0                       9.0
# 03                 11.0                      11.0
# 04                  3.0                       8.0
# 05                  2.0                      10.0
# 06                  1.0                       7.0
# 07                  2.0                       4.0
# 08                  4.0                       NaN
# 09                  7.0                       NaN
# 10                  8.0                      17.5
# 11                  5.0                      16.0
# 12                  8.0                      24.0
#
#         PHP-разработчик с 0 до PRO. Часть 1  Java-разработчик
# Месяцы
# 01                                     11.0               5.0
# 02                                      7.5               4.0
# 03                                      9.5               6.5
# 04                                     10.0               9.0
# 05                                      8.0               9.0
# 06                                      8.0               7.0
# 07                                      6.0               6.0
# 08                                     13.5              14.0
# 09                                      9.5              11.0
# 10                                     23.0               9.0
# 11                                     19.0               8.0
# 12                                      8.0               3.0

# %%
season_progress
# Out:
#         Java-разработчик c нуля  Веб-дизайн Базовый  Excel Базовый  \
# Месяцы
# 01                          NaN                 8.0            2.0
# 02                          NaN                 0.0            2.0
# 03                          6.0                12.0            2.0
# 04                          3.0                 8.0            1.0
# 05                          3.0                 6.0            2.0
# 06                          2.0                 7.0            1.0
# 07                          1.0                 7.0            1.0
# 08                          NaN                12.0            3.0
# 09                          NaN                13.0            1.5
# 10                          NaN                18.0            2.0
# 11                          NaN                 7.5            2.0
# 12                          NaN                18.0            4.0
#
#         Руководитель digital-проектов  Веб-вёрстка для начинающих 2.0  \
# Месяцы
# 01                                5.0                             9.0
# 02                                1.0                             8.5
# 03                                6.0                             8.0
# 04                                6.0                             9.0
# 05                                6.0                             8.0
# 06                                6.0                             5.0
# 07                                6.0                             3.0
# 08                               13.0                             7.0
# 09                               10.0                            10.0
# 10                                4.0                            11.0
# 11                                5.5                             9.0
# 12                                7.0                             8.0
#
#         JavaScript с нуля  Анимация интерфейсов  Веб-дизайн PRO 2.0  \
# Месяцы
# 01                    6.0                   6.0                10.0
# 02                    5.0                   2.5                 8.0
# 03                    5.5                   7.0                 7.0
# 04                    4.0                   5.0                 6.5
# 05                    5.0                   6.0                 5.0
# 06                    5.0                   4.0                 4.0
# 07                    5.0                   5.0                 8.0
# 08                    7.0                   3.0                31.0
# 09                   11.0                   7.0                27.0
# 10                   12.0                   5.0                14.5
# 11                    8.0                   8.0                10.0
# 12                    8.0                  11.0                10.0
#
#         UX-дизайн  Интернет-маркетолог от Ingate  Веб-дизайн с нуля 2.0  \
# Месяцы
# 01            9.0                            5.0                    5.0
# 02            4.0                            3.5                    6.0
# 03            9.0                            6.0                    4.0
# 04            8.0                            7.0                    4.0
# 05            8.0                            7.0                    4.0
# 06            6.0                            5.0                    3.0
# 07            6.0                            4.0                    3.0
# 08            9.5                            7.0                    7.0
# 09           11.0                            4.0                    8.0
# 10           13.0                            7.0                    7.0
# 11           10.0                            6.0                    7.0
# 12           10.0                            5.0                    7.0
#
#         Веб-разработчик  SMM-маркетолог от А до Я  \
# Месяцы
# 01                  6.0                      12.0
# 02                  3.0                       9.0
# 03                 11.0                      11.0
# 04                  3.0                       8.0
# 05                  2.0                      10.0
# 06                  1.0                       7.0
# 07                  2.0                       4.0
# 08                  4.0                       NaN
# 09                  7.0                       NaN
# 10                  8.0                      17.5
# 11                  5.0                      16.0
# 12                  8.0                      24.0
#
#         PHP-разработчик с 0 до PRO. Часть 1  Java-разработчик
# Месяцы
# 01                                     11.0               5.0
# 02                                      7.5               4.0
# 03                                      9.5               6.5
# 04                                     10.0               9.0
# 05                                      8.0               9.0
# 06                                      8.0               7.0
# 07                                      6.0               6.0
# 08                                     13.5              14.0
# 09                                      9.5              11.0
# 10                                     23.0               9.0
# 11                                     19.0               8.0
# 12                                      8.0               3.0

# %% [markdown]
# ### 3.5 Аналитический вывод

# %% [markdown]
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Java-разработчик%20c%20нуля.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Веб-дизайн%20Базовый.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Excel%20Базовый.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Руководитель%20digital-проектов.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Веб-вёрстка%20для%20начинающих%202.0.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_JavaScript%20с%20нуля.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Анимация%20интерфейсов.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Веб-дизайн%20PRO%202.0.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_UX-дизайн.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Интернет-маркетолог%20от%20Ingate.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Веб-дизайн%20с%20нуля%202.0.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Веб-разработчик.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_SMM-маркетолог%20от%20А%20до%20Я.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_PHP-разработчик%20с%200%20до%20PRO.%20Часть%201.png">
# <img width = "600" align = "left" src = "https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/MedianModule_Java-разработчик.png">

# %% [markdown]
# 1. *Выполнение домашней работы по модулям*
# <br>
# <p>В данных графиках трудно найти похожие, хотя некоторые из них приблизительно обладают схожими чертами. Например, курсы, связанные с разработкой, обладают свойством модулей *от простого к сложному* (PHP, Java-разработчик с нуля), где время выполнения ДЗ увеличивается по мере продвижения по модулям. В основном же встречаются курсы с равномерным распределением нагрузки: либо время выполнения находится примерно на одном уровне для каждого модуля, либо пики и спады чередуются таким образом, что слишеом простые модули компенсируют слишком сложные. Часто наблдается аномальное возрастание - оно присутствует в связи с наступлением курсовых, дипломных или экзаменационных работ.</p>
# <p>Дольше всего выполняются модули, связанные с дизайном или вебом. Проще всего студентам даются курсы по маркетологии/бизнесу. Сложность курсов по разработке на среднем уровне.</p>
# <p>*На курсе <i>Анимация интерфесов</i> присутствует разрыв. Скорее всего, модуль под номером 12 был добавлен позже (в виде обновления), чем студенты завершили прохождение курса.</p>

# %% [markdown]
# <img src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData3/SeasonHW.png>

# %% [markdown]
# 2. *Сезонность выполнения дз*
# <p>
#     Данный график демонстрирует то, что сезон учебы длится первые полгода, при этом о курсах <i>Java-разработчик с нуля</i> и <i>SMM-маркетолог от А до Я</i> сказать что-то трудно, поскольку они появились позднее и на графике можно заметить немалые разрывы. Насчёт остальных курсов можно сказать, что у большинства курсов сезонность сильно не наблюдаются, если только на курсах, связанных с дизайном (сильный спад продуктивности осенью, а потом восстановление прежнего режима).
# </p>

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# ### 4.1 Рассчёт помодульной конверсии

# %%
conversion_frame = pd.DataFrame(columns = ('course', 'module_finish', 'module_start', 'conversion', 'f_s'))
for course in id_title.values():
    started, finished = 0, 0
    cur_df = main[(main.title == course) & (main.is_homework == True)]
    #Отбрасываем модули, в которых нет уроков с ДЗ
    modules_wh =  list(courses[(courses.title == course) &
                               (courses.is_homework == True)].module_number.drop_duplicates())
    if course == 'Анимация интерфейсов':
        modules_wh.remove(12) #Удаляем 12-ый модуль, поскольку там к дз никто не приступал
    for module in range(len(modules_wh) - 1):
        hw1 = list(courses[(courses.title == course) &
                           (courses.module_number == modules_wh[module]) &
                           (courses.is_homework == True)].lesson_token)[-1]
        hw2 = list(courses[(courses.title == course) & 
                           (courses.module_number == modules_wh[module + 1]) &
                           (courses.is_homework == True)].lesson_token)[0]

        len1 = len(cur_df[(cur_df.status == 'done') & (cur_df.lesson_token == hw1)]) # Завершившие предыдущий модуль
        len2 = len(cur_df[cur_df.lesson_token == hw2]) # Приступившие к следующему модулю
        conversion_frame.loc[len(conversion_frame)] = (course, 
                                                        modules_wh[module],
                                                        modules_wh[module + 1],
                                                        len2/len1 if len1!=0 else None, 
                                                        f'{modules_wh[module]}-{modules_wh[module + 1]}')

# %%
conversion_frame
# Out:
#                                   course module_finish module_start  \
# 0                Java-разработчик c нуля             1            2
# 1                Java-разработчик c нуля             2            3
# 2                Java-разработчик c нуля             3            4
# 3                Java-разработчик c нуля             4            5
# 4                Java-разработчик c нуля             5            6
# 5                Java-разработчик c нуля             6            7
# 6                Java-разработчик c нуля             7            8
# 7                Java-разработчик c нуля             8            9
# 8                     Веб-дизайн Базовый             3            5
# 9                     Веб-дизайн Базовый             5            6
# 10                    Веб-дизайн Базовый             6            7
# 11                    Веб-дизайн Базовый             7            8
# 12                    Веб-дизайн Базовый             8            9
# 13                    Веб-дизайн Базовый             9           10
# 14                    Веб-дизайн Базовый            10           11
# 15                    Веб-дизайн Базовый            11           12
# 16                    Веб-дизайн Базовый            12           13
# 17                    Веб-дизайн Базовый            13           14
# 18                    Веб-дизайн Базовый            14           17
# 19                         Excel Базовый             1            2
# 20                         Excel Базовый             2            3
# 21                         Excel Базовый             3            4
# 22                         Excel Базовый             4            5
# 23                         Excel Базовый             5            6
# 24                         Excel Базовый             6            7
# 25                         Excel Базовый             7            8
# 26                         Excel Базовый             8            9
# 27         Руководитель digital-проектов             1            2
# 28         Руководитель digital-проектов             2            3
# 29         Руководитель digital-проектов             3            4
# ..                                   ...           ...          ...
# 145                      Веб-разработчик            14           15
# 146                      Веб-разработчик            15           18
# 147             SMM-маркетолог от А до Я             1            2
# 148             SMM-маркетолог от А до Я             2            3
# 149             SMM-маркетолог от А до Я             3            4
# 150             SMM-маркетолог от А до Я             4            5
# 151             SMM-маркетолог от А до Я             5            6
# 152             SMM-маркетолог от А до Я             6            8
# 153  PHP-разработчик с 0 до PRO. Часть 1             1            2
# 154  PHP-разработчик с 0 до PRO. Часть 1             2            3
# 155  PHP-разработчик с 0 до PRO. Часть 1             3            4
# 156  PHP-разработчик с 0 до PRO. Часть 1             4            5
# 157  PHP-разработчик с 0 до PRO. Часть 1             5            6
# 158  PHP-разработчик с 0 до PRO. Часть 1             6            7
# 159  PHP-разработчик с 0 до PRO. Часть 1             7            8
# 160                     Java-разработчик             1            2
# 161                     Java-разработчик             2            3
# 162                     Java-разработчик             3            4
# 163                     Java-разработчик             4            5
# 164                     Java-разработчик             5            6
# 165                     Java-разработчик             6            7
# 166                     Java-разработчик             7            8
# 167                     Java-разработчик             8            9
# 168                     Java-разработчик             9           10
# 169                     Java-разработчик            10           11
# 170                     Java-разработчик            11           12
# 171                     Java-разработчик            12           13
# 172                     Java-разработчик            13           14
# 173                     Java-разработчик            14           15
# 174                     Java-разработчик            15           17
#
#      conversion    f_s
# 0      0.985866    1-2
# 1      0.954751    2-3
# 2      1.080000    3-4
# 3      0.963636    4-5
# 4      0.986667    5-6
# 5      1.083333    6-7
# 6      0.891892    7-8
# 7      1.000000    8-9
# 8      0.954802    3-5
# 9      0.990741    5-6
# 10     0.985612    6-7
# 11     1.000000    7-8
# 12     0.991379    8-9
# 13     1.004717   9-10
# 14     1.011050  10-11
# 15     1.017442  11-12
# 16     1.012903  12-13
# 17     1.026846  13-14
# 18     1.098361  14-17
# 19     0.947598    1-2
# 20     0.980296    2-3
# 21     0.891473    3-4
# 22     0.983498    4-5
# 23     0.974074    5-6
# 24     0.983471    6-7
# 25     1.010000    7-8
# 26     1.026882    8-9
# 27     0.958929    1-2
# 28     1.072000    2-3
# 29     0.971014    3-4
# ..          ...    ...
# 145    1.152174  14-15
# 146    1.303030  15-18
# 147    0.818182    1-2
# 148    0.948276    2-3
# 149    0.564356    3-4
# 150    1.217391    4-5
# 151    5.055556    5-6
# 152    0.969231    6-8
# 153    0.855305    1-2
# 154    1.307692    2-3
# 155    1.024000    3-4
# 156    1.137500    4-5
# 157    1.055556    5-6
# 158    0.981818    6-7
# 159    1.194444    7-8
# 160    0.925400    1-2
# 161    0.875878    2-3
# 162    0.962585    3-4
# 163    0.931034    4-5
# 164    1.011561    5-6
# 165    0.987500    6-7
# 166    0.957746    7-8
# 167    1.056604    8-9
# 168    1.013514   9-10
# 169    1.045455  10-11
# 170    1.019608  11-12
# 171    1.064516  12-13
# 172    0.961538  13-14
# 173    1.043478  14-15
# 174    1.105263  15-17
#
# [175 rows x 5 columns]

# %% [markdown]
# ### 4.2 Графики конверсий (вертикальные бар-чарты)

# %%
from matplotlib import pyplot as plt
for course in id_title.values():  
    rmc()
    fig, subplot = plt.subplots()
    cur_frame = conversion_frame[conversion_frame.course == course]
    subplot.bar(cur_frame.module_start, cur_frame.conversion)
    subplot.set_title(f'Конверсия модулей на курсе {course}')
    plt.xticks(ticks = cur_frame.module_start, labels = cur_frame.module_start.apply(str), rotation = 'vertical')
    plt.savefig(f"CreatedData4/ConversionBar_{course}.png", bbox_inches = 'tight')
# разрывы - это модули, в которых нет дз

# %% [markdown]
# ### 4.3 Отформатированные графики конверсий (горизонтальные бар-чарты)

# %%
# список из имён модулей
conversion_modname = {i:list() for i in id_title.values()}
for course, mod in (tuple(zip(list(conversion_frame.course), 
                    list(conversion_frame.module_start)))):
    conversion_modname[course].append(str(course_legend[(course_legend['Курс'] == course) &
                      (course_legend['Номер модуля'] == mod)].reset_index()['Модуль'][0]) + f'({mod})')

# %%
conversion_modname
# Out:
# {'Java-разработчик c нуля': ['Синтаксис языка(2)',
#   'Объекты и классы(3)',
#   'Числа, строки и даты(4)',
#   'Массивы и коллекции(5)',
#   'Наследование и полиморфизм(6)',
#   'Особенности ООП в Java(7)',
#   'Исключения, отладка, тестирование и логгирование(8)',
#   'Работа с файлами и сетью(9)'],
#  'Веб-дизайн Базовый': ['Основы работы с графикой. Практика Photoshop(5)',
#   'Графика для сайтов(6)',
#   'Формы и кнопки. Практика Photoshop(7)',
#   'Формы и кнопки: интерактивные элементы(8)',
#   'Универсальные элементы сайтов. Практика Photoshop(9)',
#   'Цвет, атмосфера, тексты и здравый смысл(10)',
#   'Интерактивные элементы. Практика Photoshop(11)',
#   'Интерактивные элементы(12)',
#   'Инфографика. Практика Photoshop(13)',
#   'Инфографика: как сделать сайты интересными(14)',
#   'Дипломная работа(17)'],
#  'Excel Базовый': ['Основной функционал Excel (продолжение)(2)',
#   'Формулы и функции Excel. Введение(3)',
#   'Формулы и функции Excel. Продолжаем работать с формулами(4)',
#   'Формулы и функции Excel. Более сложные формулы(5)',
#   'Формулы и функции Excel. Работа с ошибками, проверка данных(6)',
#   ' Визуализация данных Excel(7)',
#   'Сводные таблицы Excel(8)',
#   'Экзаменационная работа (9)'],
#  'Руководитель digital-проектов': ['Релиз-менеджмент: готовим проекты к запуску(2)',
#   'Требовательность digital-продюсера(3)',
#   'Аналитика. Базовые навыки(4)',
#   'Как пасти котов: правильное делегирование в IT(5)',
#   'Переговорные навыки. Часть 1. Цикл продаж(6)',
#   'Переговорные навыки. Провокации. Работа с возражениями. Часть 2.(7)',
#   'Оценка и декомпозиция digital-проектов(8)',
#   'Управление временем(9)',
#   'Scrum: передовая методология управления современными digital-проектами. Часть 1.(10)',
#   'Scrum. Передовая методология управления digital-проектами. Часть 2.(11)',
#   'Решение факапов. Lean/TOC. Обзор.(12)',
#   'Интеграционные проекты.(13)',
#   'Управление дизайнерами. Разработка дизайна по scrum(14)',
#   'Основы технической грамотности(15)',
#   'Контроль. Риски. Поощрения. Наказания. Обратная связь.(16)'],
#  'Веб-вёрстка для начинающих 2.0': ['HTML(2)',
#   'Основы CSS(3)',
#   'Основы JavaScript(4)',
#   'Адаптивность и кроссбраузерность(5)',
#   'Оформление(6)',
#   'Advanced CSS(7)',
#   'Инструменты верстальщика(8)'],
#  'JavaScript с нуля': ['Основы(2)',
#   'Функции(3)',
#   'Массивы и объекты(4)',
#   'Замыкания(5)',
#   'Объекты и конструкторы(6)',
#   'Объектно-ориентированное программирование(7)',
#   'Разное(8)',
#   'JavaScript в браузере; DOM(9)',
#   'Web API(10)',
#   'Клиент и сервер(11)',
#   'jQuery(12)',
#   'Современный JavaScript; ES 2015(13)',
#   'Сборка проектов(14)',
#   'React(15)',
#   'Redux(16)',
#   'Экзаменационное задание(18)'],
#  'Анимация интерфейсов': ['12 принципов анимации от Walt Disney Studio(2)',
#   'Motion design в интерфейсах(3)',
#   'After Effects(4)',
#   'Иконки — погружение в мир микроанимации(5)',
#   'Прелоадеры(7)',
#   'Material Design(8)',
#   'Principle (обновлён 06.06.19)(10)',
#   'Webflow — инструмент прототипирования веб-интерфейсов(11)',
#   'Анимация статичной концепции(13)',
#   'Видеобаннеры. Тренд, который заслуживает внимания(14)',
#   'Анимация концепции для презентации клиенту(15)',
#   'Чистая магия — cоздание продающего шоурила(18)',
#   'Дипломная работа(21)'],
#  'Веб-дизайн PRO 2.0': ['Концептуальный дизайн(2)',
#   ' Введение в UX(4)',
#   'Портреты пользователей и CJM(5)',
#   'Иконки(6)',
#   'Типографика PRO(7)',
#   'Readymag(9)',
#   'Продвинутая презентация(10)',
#   'Копирайтинг(12)',
#   'Cinema 4D + Blender(13)',
#   'Adobe XD(14)',
#   'Кейс на 1000 лайков(15)',
#   'План развития дизайнера на 3 года(16)'],
#  'UX-дизайн': ['Основные этапы проекта(2)',
#   'Service design: теория и практика(3)',
#   'UX-проектирование. Паттерны и психология пользователя(4)',
#   'UX-проектирование. Исследование интерфейсов(6)',
#   'Data driven design: теория и практика(7)',
#   'Concept design: творчество в дизайне(9)',
#   'Visual design теория и практика(11)',
#   'Техника успешной презентации(13)',
#   'Специализация и карьера(19)',
#   'Экзаменационная тема(20)'],
#  'Интернет-маркетолог от Ingate': ['Исследование целевой аудитории: портретирование, анализ сайта, Customer Journey Map  (обновление от 18 марта 2019 г)(2)',
#   'SEO: больше, чем поисковая выдача (обновление от 30 января 2019 г)(3)',
#   'Управление репутацией (SERM)(4)',
#   'Медийная реклама и RTB: охват или целевые пользователи?(5)',
#   'Контекстная реклама в Yandex Direct и Google Adwords (обновление от 6 марта 2019 г)(6)',
#   'Маркетплейсы(7)',
#   'SMM (обновление от 15 февраля 2019 г)(8)',
#   'Таргетированная реклама в социальных сетях(9)',
#   'Контент-маркетинг: стратегия коммуникации, каналы и инструменты(10)',
#   'Партнерский CPA-маркетинг(11)',
#   'Медиапланирование: разработка комплексной стратегии и ее оценка(12)',
#   'Веб-аналитика: максимум информации об эффективности сайта, источниках трафика и целевой аудитории(13)',
#   'Юзабилити: разработка эффективного сайта(14)',
#   'Построение маркетинговой структуры и работа с командой(15)',
#   'Email-маркетинг(16)',
#   'Юридическая сторона рекламы(17)',
#   'Финальное тестирование(18)'],
#  'Веб-дизайн с нуля 2.0': ['Тренды, подготовка, мудборды(3)',
#   'Работа со стилями. Создание GUI(4)',
#   'Главная страница, первые шаги(5)',
#   'Основы работы с графикой(7)',
#   'Декомпозиция(9)',
#   'Навигация и структура(10)',
#   'Интересная подача информации(11)',
#   'Формы и кнопки(12)',
#   ' Адаптивность и мобильная версия(13)',
#   'Цвета, настроение. Промо-страница мероприятия.(14)',
#   'Декомпозиция промо-страницы(15)',
#   '3D-элементы в Photoshop(16)',
#   'Презентация для клиента(17)',
#   'Передача проекта в верстку(18)',
#   'Первый кейс на Behance(19)'],
#  'Веб-разработчик': ['HTML. Общая структура HTML-документа(2)',
#   'HTML. Формы(3)',
#   'Позиционирование при помощи CSS(4)',
#   'CSS. Знакомство со стилями(5)',
#   'Знакомство с JavaScript(6)',
#   'Javascript – события. Модель обработки событий(7)',
#   'Javascript – события часть 1 (8)',
#   'Javascript – события часть 2(9)',
#   'PHP. Место в структуре сайта(10)',
#   'PHP. Пользовательские функции(11)',
#   'PHP. Генерация, работа  с изображениями(12)',
#   'PHP. Работа с файловой системой(13)',
#   'PHP. Взаимодействие  с браузером(14)',
#   'SQL БД. Концепция, назначение(15)',
#   'Экзаменационная работа (18)'],
#  'SMM-маркетолог от А до Я': ['Разработка стратегии продвижения в Social Media(2)',
#   'Разработка креативных решений(3)',
#   'Дизайн для не дизайнеров(4)',
#   'Как писать хорошие тексты(5)',
#   'Продвижение в VK, FB, MyTarget(6)',
#   'Коммьюнити-менеджмент(8)'],
#  'PHP-разработчик с 0 до PRO. Часть 1': ['Структура управления данными. Базовые концепции PHP 7(2)',
#   'Протокол HTTP/HTTPS(3)',
#   'Пользовательские функции(4)',
#   'Файлы и каталоги(5)',
#   'Cookie/Session(6)',
#   'База данных MySQL(7)',
#   'Курсовая работа(8)'],
#  'Java-разработчик': ['Синтаксис языка(2)',
#   'Объекты и классы(3)',
#   'Числа, строки и даты(4)',
#   'Массивы и коллекции(5)',
#   'Наследование и полиморфизм(6)',
#   'Тестирование и отладка(7)',
#   'Основы построения GUI(8)',
#   'Внешний вид GUI и рисование(9)',
#   'Работа с файлами и сетью(10)',
#   'Работа с базами данных(11)',
#   'Многопоточность(12)',
#   'Оптимизация кода и приложений(13)',
#   'Основы построения веб-приложений(14)',
#   'Веб-приложения: формы, заголовки и сессии(15)',
#   'Итоговая тема(17)']}

# %%
for course in id_title.values():
    fig, subplot = plt.subplots()
    subplot.barh(conversion_frame[conversion_frame.course == course].f_s, 
                 conversion_frame[conversion_frame.course == course].conversion, 
                 color = field_color[course_field[course]],
                 alpha = 0.1)
    subplot.set_title(f'Конверсия модулей на курсе {course}')
    subplot.legend(rect, tuple(field_color.keys()))
    med = np.median(conversion_frame[conversion_frame.course == course].conversion)
    subplot.vlines(med,-0.4,len(conversion_frame[conversion_frame.course == course]), color = 'brown')
    subplot.spines['top'].set_visible(False)
    subplot.spines['right'].set_visible(False)
    subplot.spines['bottom'].set_visible(False)
    subplot.spines['left'].set_visible(False)
    plt.yticks(range(len(conversion_modname[course])), labels = conversion_modname[course])
    plt.savefig(f"CreatedData4/ConversionBar_{course}_format.png", bbox_inches = 'tight')

# %% [markdown]
# ### 4.4 Аналитический вывод

# %% [markdown]
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Java-разработчик%20c%20нуля.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Веб-дизайн%20Базовый.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Excel%20Базовый.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Руководитель%20digital-проектов.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Веб-вёрстка%20для%20начинающих%202.0.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_JavaScript%20с%20нуля.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Анимация%20интерфейсов.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Веб-дизайн%20PRO%202.0.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_UX-дизайн.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Интернет-маркетолог%20от%20Ingate.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Веб-дизайн%20с%20нуля%202.0.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Веб-разработчик.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_SMM-маркетолог%20от%20А%20до%20Я.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_PHP-разработчик%20с%200%20до%20PRO.%20Часть%201.png>
# <img align = "left" height = "150" src = https://raw.githubusercontent.com/VArrow2001/SkillboxHomeworks/master/Course_1/CreatedData4/ConversionBar_Java-разработчик.png>

# %% [markdown]
# Конверсия по модулям колеблется, в среднем, от *0,1* до *0,4*. В виде аномалий (в основном, последние модули) можно встретить резкий рост. Скорее всего, это означает, что определённый набор студентов (достаточно большое количество) подходит к концу выполнения курса (или же просто, где в среднем находится конкретный набор). Проводя другие исследования, по конверсии можно выявить наиболее сложные модули для студентов (самые высокие столбцы). Наибольшая конверсия встречается в модуле *SMM-маркетолог*. Далее, лидирующие позиции занимают *Анимация интерфейсов, UX-дизайн, PHP-Разработка и Веб-разработка*.

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %% [markdown]
# ### 5.1 Определение критериев успеваемости/неуспеваемости

# %% [markdown]
# Сделаем 4-хбалльную систему оценивания, похожую на общепринятую 5-ибалльную. На основе пункта *3.1* выявим степени успеваемости по времени выполнения модулей:
# * 1 балл: от нормы стандартного отклонения до максимума <div>(mean+stdp; max]</div> неуд.
#
# * 2 балла: от среднего значения до нормы стандартного отклонения <div>\[mean; mean+stdp\]</div> уд.
#
# * 3 балла: от нормы стандартного отклонения <div>[mean-stdn; mean)</div> хор.
#
# * 4 балла: от минимума до нормы стандартного отклонения <div>[min; mean-stdn)</div> отл.

# %% [markdown]
# Также в расчет будем брать студентов, выполнение заданий у которых не завершено на момент августа 2019 года и разница между началом выполнения модуля и этим месяцем больше допустимого максимума, или находится в диапазоне 1 балла.

# %% [markdown]
# Неуспевающих будем искать среди студентов, которые не выполнили последний модуль курса. Сначала будет необходимым создание словаря/датафрейма с баллами студентов за каждый модуль. В результате, если медианное значение баллов студента будет равно 1, он будет причислен к лиге неуспевающих студентов.

# %% [markdown]
# #### Актуальность
# Такая метрика хороша тем, что её объективность локальна. Т.е. мы не измеряем все модули по каким-то внешним стандартам и не устанавливаем единую шкалу оценивания, а определяем эти стандарты отдельно для каждого модуля каждого курса. Да, мы основывемся на общем принципе построения алгоритма, но при этом сохраняется "индивидуальный подход" к каждому курсу.

# %% [markdown]
# ### 5.2 Реализация метрики

# %%
# в пункте 3.1 я изменил алгоритм немного, чтобы датафрейм les_p_mod 
# заполнился стандартными отклонениями в меньшую и большую сторону,
# также добавил start_token и finish_token для упрощения нахождения
# прохождения модулей.

# %%
# создание списка действительных студентов
studset = list(set(main.student_id))
marks_df = pd.DataFrame(columns = ('student_id',
                                   'course',
                                   'mean',
                                   'status'))
august = "2019-08-01 00:00:00"
length = len(studset)
k = 0
first = datetime.now()
for student in studset:
    k += 1
    marks = []
    cur_df = main[(main.student_id == student) & (main.is_homework == True)]
    # убираем слишком мало выполнивших студентов
    if len(cur_df) == 1:
        continue
    
    # убираем тех, кто не выполнил ни одного дз
    if len(cur_df[cur_df.is_homework == True]) == 0:
        continue
    cur_df.reset_index(inplace = True)
    cur_course = set(cur_df.reset_index().title)
    maxi = 0
    course_ = None
    # находим курс-моду: курс, по которому студент прошел больше всего уроков
    for i in cur_course:
        l = len(cur_df[cur_df.title == i])
        if l > maxi:
            maxi = l
            course_ = i
    cur_course = course_
    last_lesson = les_p_mod[(les_p_mod['Название курса'] == cur_course)]
    last_lesson = last_lesson.reset_index().iloc[len(last_lesson) - 1]
    last_lesson = [last_lesson['Название модуля'], last_lesson['Количество уроков']]
    
    # отбираем студентов, не завершивших курс
    if len(cur_df[(cur_df.module_title == last_lesson[0]) &
              (cur_df.lesson_number == last_lesson[1]) &
              (cur_df.status == 'done')]) == 0:
        modules = sorted(list(set(cur_df[cur_df.title == cur_course].module_title)))
        for mod in modules:
            if mod == 'InVision Studio':
                continue
            cur_mod = les_p_mod[(les_p_mod['Название курса'] == cur_course) &
                              (les_p_mod['Название модуля'] == mod)]
            if len(cur_mod) == 0:
                continue
            cur_mod.reset_index(inplace = True)
            start = cur_mod.start_token[0]
            finish = cur_mod.finish_token[0]
            try:
                start = cur_df[cur_df.lesson_token == start].reset_index().start_date[0]
            except:
                continue
            if len(cur_df[cur_df.lesson_token == finish]) > 0:
                finish = cur_df[cur_df.lesson_token == finish].reset_index().finish_date[0]
            else: 
                finish = august
            if str(finish) == 'nan':
                finish = august
            delta = to_date(finish) - to_date(start)
            days = delta.days
            # отбрасываем случаи, когда первое дз выполнялось позже последнего и выставляем оценку
            if days >= 0:
                mini = cur_mod['Минимум'][0]
                maxi = cur_mod['Максимум'][0]
                mean = cur_mod['Среднее'][0]
                stdp = cur_mod['standart_deviation_p'][0]
                stdn = cur_mod['standart_deviation_n'][0]
                mark = None
                if mini <= days < mean - stdn:
                    mark = 4
                elif mean - stdn <= days < mean:
                    mark = 3
                elif mean <= days <= mean + stdp:
                    mark = 2
                elif mean + stdp <= days <= maxi:
                    mark = 1
                else:
                    mark = 0
                marks.append(mark)
                
        # обходим, если по непонятным причинам оценок не выявлено
        if len(marks) == 0:
            continue
        # выставляем вердикт - степени успеваемости
        if (np.mean(marks) < 1):
            marks_df.loc[len(marks_df)] = (student,
                                          cur_course,
                                          np.mean(marks),
                                          'lags a lot')
        elif np.mean(marks) < 1.5:
            marks_df.loc[len(marks_df)] = (student,
                                          cur_course,
                                          np.mean(marks),
                                          'lags')
        elif np.mean(marks) < 2:
            marks_df.loc[len(marks_df)] = (student,
                                          cur_course,
                                          np.mean(marks),
                                          'lags a bit')
        if str(np.mean(marks)) == 'nan':
            break
marks_df.to_html('CreatedData5/AcademicPerformance.html')

# %% [markdown]
# Внизу представлен список неуспевающих студентов. Степень *неуспеваемости* ранжируется следующим образом:
# * < 1: lags a lot - группа самых неуспевающих
# * < 1.5: lags - группа отстающих
# * < 2: lags a bit - группа студентов, отстающих периодически.

# %% [markdown]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>student_id</th>
#       <th>course</th>
#       <th>mean</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>f60f2b219c3eb3182862729bbb75a05e</td>
#       <td>UX-дизайн</td>
#       <td>0.333333</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>d38e9e540c2c300371a012dc9f5f0214</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>72f774720584876a390848e99f4f18c3</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5827bb56b51b7a749be2ecaaa200d4d4</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>acbd0baef1f2438797447e793adf2c0a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>fe67b354fcd99aa081987b0ce5dbbb54</td>
#       <td>Java-разработчик</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>35a6d7767998efde65b394e0b8b962c2</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>064f9cd14f7450887999ecc449665638</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>5d5224c6ce7597cfb1f94f9d5ef42947</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>04ba196254f775ff03aaee0aa6525c02</td>
#       <td>Java-разработчик</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>99db6b35c43ae8814ef644a7595ab80b</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>ffb2ea9eebdc7dde3a003a65e3ff41ee</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>bc6267d77785f613527e5cce2040701a</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.916667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>62d1b6e5d0cd07e71c12b8980bf5d23d</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1c03f238ee039a83faa9235af327859a</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>36765f094a50fe69ab45239b735c94e7</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>cbabb9013268234a282e44151195d88f</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>f099a3cd4c6e74e71057a90552a8068b</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>abcfc06efa94cb3e5467c3a833af3730</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>d8fc78038212d325427f6501893c7432</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>fcb83cf700c35715a8333b0e16d09a2d</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>8c805a0e1b308ae231b2d7c7aa7956e2</td>
#       <td>Веб-разработчик</td>
#       <td>0.142857</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>88469d81e0ff7f27619a8974b4952cdf</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>c008c64a8c350ef2bc46adad84c3bfd7</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>26dfd477345a7c34d78d9a1cebfbcf80</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>5e0249925f38aac5ada2a373ceb6cad1</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>e85a41cd3f98ee47d32c5413581dbc7d</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.937500</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>56c003bcfd76dd2d51f35b918c33b838</td>
#       <td>Java-разработчик</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2af0d366faef24285f072444e4327699</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>eb972a4b29289d157d0277ddeb625d97</td>
#       <td>Java-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>5eb5736f0e962311b9a062517fedb439</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>9d2e99286028008f723df21c9ddba284</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>ab2604e0a56fc57dd917cb79bb5af930</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>9b64794041603382adae6ce760e285d8</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>cd85fb983dfc4aff3b0b58cf4a49756a</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>8978b6bdadfe6c5b5db5852e51afdd74</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.700000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>e2af0de8c531e420111181a195b7be32</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>e351c68450022ddcc9d5465e22994af7</td>
#       <td>Java-разработчик</td>
#       <td>1.727273</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>32a53747ce2f34ea33a153205fa62ae9</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>cb665d23918ef3165cd4a53ea1190963</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>90684c9ba9628e6c24f0cc3e2339c31e</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>a28c35fe1eaeb4437443bdb0032f2bda</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>37dbe9e429e9b9e6f448e6bcec0683bd</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>509a2a78cf2d62fc64f79559ec59f3eb</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>34b6ca3497f307e9ea46d4de32322094</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>0.750000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>3a132407011332342c0c20e8149698ad</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>451ede5850451337ada2468915b36598</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>184f24b91f530e2e0e02f39d2a3bb46d</td>
#       <td>Веб-разработчик</td>
#       <td>1.100000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td
разработчик</td>
#       <td>0.000000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>500</th>
#       <td>04b23a353793bcb292e3ec1e1b87a8ef</td>
#       <td>Excel Базовый</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>501</th>
#       <td>b3d7daeb2f87734226e5ac9195f8c2bd</td>
#       <td>Веб-разработчик</td>
#       <td>1.625000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>502</th>
#       <td>56473fa7627397dce3aa1f53be959f9f</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>503</th>
#       <td>8a9a4edd73b94f6048104c41751f9959</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>504</th>
#       <td>00a99ffcb76cc03dda6b3210d4849f52</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>505</th>
#       <td>b574456f71aa12f7c05b6d5f5bc7af64</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>506</th>
#       <td>e671a94135ac2aac27ebb20273576187</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>507</th>
#       <td>3962499216b96e7313074b1b83e6872f</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>508</th>
#       <td>dc4207d563e9f806f4d5bf9c48aac7a9</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>509</th>
#       <td>ba3cb1e4a1821707a48967def29a49f4</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>510</th>
#       <td>370c3852f9c1b4cdbd909f7f4c9c7e6c</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>511</th>
#       <td>cd941875eb17f56fb8e08824b0678316</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>512</th>
#       <td>773f0d7bef4f936fa24346d914321c35</td>
#       <td>Excel Базовый</td>
#       <td>1.555556</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>513</th>
#       <td>d60468abb6208b6a5be8b12a79bdeca2</td>
#       <td>Java-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>514</th>
#       <td>c4cfd020cb6e4b37d26e68fdaf022db8</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>515</th>
#       <td>0565651d654e647e36fb474eae15cb4e</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>516</th>
#       <td>8b86d21a719838cadfc9b4315a1f8269</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>517</th>
#       <td>d9eb6612c413f2fdc020ae5708fdb1e7</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>518</th>
#       <td>6808c5ad11a03547fc2d0eb830539598</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>519</th>
#       <td>bfa5f05e3588a81a256a1136cb2af7e2</td>
#       <td>Java-разработчик</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>520</th>
#       <td>216e138916e28150897ca6a734e4e3f1</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>521</th>
#       <td>9621f04de041c777e183919d17c9e765</td>
#       <td>Excel Базовый</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>522</th>
#       <td>62b76d87eae276b1387bc67a0d7f4e8d</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>523</th>
#       <td>a15a780f3f03ce4210756d342724de05</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>524</th>
#       <td>45d54bc4deabc09c46561903d049c40d</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>525</th>
#       <td>62863d9835b9e936584a4d8b15adea8a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>526</th>
#       <td>44e0d5c5f3dc19475f1f313a397ad7f8</td>
#       <td>Веб-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>527</th>
#       <td>01090ac16739af7742abd453e4e947b0</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>528</th>
#       <td>7c5593f2090d49b38fb362c6b14010e5</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>529</th>
#       <td>81d289dd686d1de777cb3d15e4ff03e2</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>530</th>
#       <td>a475acd5c27bb0abc57c21a4f7f3f169</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.571429</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>531</th>
#       <td>b965c5745d7c75cf6510943909e1651c</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>532</th>
#       <td>fb22194fe47d0ef50594898d6c6ab2e5</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>533</th>
#       <td>f0ccd4de7261509e42d90392b19f0922</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>534</th>
#       <td>9b712e944476fe421a25ac070aa30984</td>
#       <td>Веб-разработчик</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>535</th>
#       <td>76664b2ffc94fecf162f5b0d94ee79f3</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>536</th>
#       <td>d029b5746c79ad6c3b146ac26f3efebf</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>537</th>
#       <td>b0eedd8df081e9a223b68f110653dc84</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>538</th>
#       <td>f5c0bce70ea7bb91fc7019ea9ab3425f</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>539</th>
#       <td>f0bf758d82a7fb26793f6f8b63720282</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>540</th>
#       <td>7ccda1c59bd8caf6cd55ed8f8035b9dc</td>
#       <td>UX-дизайн</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>541</th>
#       <td>b20648e4230f9ed69dc526031ad1e19b</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>542</th>
#       <td>6ea4764a2ab14f7321b9aa4b58b63fc1</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>543</th>
#       <td>2c71dbddde0ae84fe462acc10bf163d7</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>544</th>
#       <td>ac0f32346e5753f95f0c629fa3a3c421</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>545</th>
#       <td>f11b639244ba9592e5795e0fdd531397</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>546</th>
#       <td>5c133b73eecb3743a4caa59820d3bd6b</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>547</th>
#       <td>5e87043b1eea10f135fd38b3bcf7f2ad</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>548</th>
#       <td>96e927e1655155a59f8786f9bb0bcde1</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>549</th>
#       <td>beb878afb51ed514244a0458db430734</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>550</th>
#       <td>e1d19c4c10e42cada729bfa25de95f08</td>
#       <td>Java-разработчик</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>551</th>
#       <td>c8f0909a0c6530b5d8fd68f9596a6c5b</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>552</th>
#       <td>577a67f7ecdaab6a1bbdb9e66d456228</td>
#       <td>Веб-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>553</th>
#       <td>8399339d43ac28d504b34a38333666c5</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>554</th>
#       <td>cc062112a89116108c625c68fba27be6</td>
#       <td>UX-дизайн</td>
#       <td>1.600000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>555</th>
#       <td>d9c309859a23b7497c2ea04dd140a92c</td>
#       <td>Java-разработчик</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>556</th>
#       <td>55a25ce664c2fcd676c17920d44b4c0e</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>557</th>
#       <td>7285b4c33ba21ec51b45dea774cc602a</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>558</th>
#       <td>989e7c7e8930581285475a74a59cc788</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>559</th>
#       <td>670be7caca12b82fb8e02984457281c5</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>560</th>
#       <td>922a1f8668712e1053834dfea943b334</td>
#       <td>Java-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>561</th>
#       <td>d013dd5857f0a668be67bccd521de5e8</td>
#       <td>UX-дизайн</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>562</th>
#       <td>1b73222781166a8a9b44dedd612a9cd5</td>
#       <td>Excel Базовый</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>563</th>
#       <td>3efdebd00ec002b8e586d108cfe3e0d4</td>
#       <td>Java-разработчик</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>564</th>
#       <td>8d74d1aee5132fc301d507d60d6e0d22</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>565</th>
#       <td>30c04c514d76b35f838b45679ba807ab</td>
#       <td>JavaScript с нуля</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>566</th>
#       <td>0d4f353db8a7faf24ec6ea3c25f42827</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>567</th>
#       <td>309b998f07295f160b7e16022d5a924f</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.727273</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>568</th>
#       <td>28fb6ecb5d94b95ea28f4247e1d71424</td>
#       <td>Excel Базовый</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>569</th>
#       <td>7722d90164573423e93952bfc9dfa99a</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>570</th>
#       <td>d936003d0c0752bac6438a3eec8b29d2</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>571</th>
#       <td>e7931caf9fbb6ea9dfe7c21ab2b9b1f7</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>572</th>
#       <td>ce3337f5e6af677a28bb87bf9b76b926</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.692308</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>573</th>
#       <td>39d9a809967b72f387fb49afcda997b7</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>574</th>
#       <td>f2b7de6f1d8c6e015a66a04fdc6314b5</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>575</th>
#       <td>c93c74667933cbf745b8b3030854e987</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>95be9aaa605f7961802fbf62a41b0e7c</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>577</th>
#       <td>43930003367386a2d305c1c691e78d2c</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>578</th>
#       <td>ef23de9c7270675759c328a3d671f7be</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>579</th>
#       <td>43bf32bb9bceceb0d61be1a813e70a11</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>580</th>
#       <td>affbaeba84cf32a16d04e1a8f60badfc</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>581</th>
#       <td>a1839e1735148449e9e5e15f29f97a5c</td>
#       <td>JavaScript с нуля</td>
#       <td>1.600000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>582</th>
#       <td>262688af857976603f33dfc310168cfb</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>583</th>
#       <td>25e0e7bb7c64ef5858e17b789b05ca11</td>
#       <td>JavaScript с нуля</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>584</th>
#       <td>950c5f8466397fe1d162dde92236bb84</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>585</th>
#       <td>68e9247dbafbbfb3e8b024b5bc32ff4e</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>586</th>
#       <td>29f9f1e70933df8242db0d385c168787</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th
td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>721</th>
#       <td>18a2be86430298b446c15ca2cb0d22f0</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>722</th>
#       <td>3f013f86cb8f1a910d83c5b2afae6309</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>723</th>
#       <td>689bd8965971fed67443064111dbe020</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>724</th>
#       <td>14c5119057c67f5d783d15af8dd501cb</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>725</th>
#       <td>fb22db2501a7ba133a65205f1f7e7f96</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>726</th>
#       <td>5a5fa57f8f8e09dc50b75a6bf96187d7</td>
#       <td>Веб-разработчик</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>727</th>
#       <td>21ddad9962cb2db70e544d07ee6b6e77</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.916667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>728</th>
#       <td>b13139cd7d0ce078dbaac25035634500</td>
#       <td>Веб-разработчик</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>729</th>
#       <td>f583e9ccedef0883318538a92d80d607</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>730</th>
#       <td>f6ae3f5cd03cf779d03521b81faa4d8b</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>731</th>
#       <td>5422028d148f9c084c791d6a62d3ae28</td>
#       <td>JavaScript с нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>732</th>
#       <td>e802c1607a63b1d9c959f645d199a9b5</td>
#       <td>UX-дизайн</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>733</th>
#       <td>63cb9fdf5f72ac6810fa1bd5facad99e</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>734</th>
#       <td>0dd0330cc307bd54101f7ae3ea3d6e1e</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>735</th>
#       <td>39586fc0b896f0e2d6502a0e464286ab</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>736</th>
#       <td>24275cecfb45badfcf7c5dac89c916ae</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>737</th>
#       <td>11bfa3bdfe2ea453f3cc6bcd3fa43de9</td>
#       <td>Java-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>738</th>
#       <td>09cf5a5e0beb947a45d2497b19dddc77</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>739</th>
#       <td>a16022f1dabd51d4434ffbe28d558dfd</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>740</th>
#       <td>76f2bb6d4831862f120e19149840bf1a</td>
#       <td>Excel Базовый</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>741</th>
#       <td>48426b9e617f287bef2a527c6534520a</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>742</th>
#       <td>a9f14c33a7830eda70c0e5fdfc34369a</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>743</th>
#       <td>59e2970eec232347b680cb76e6b502f2</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>744</th>
#       <td>c0f8b0c70765a109b03ba344e5583ea7</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>745</th>
#       <td>cc0d99623b59fcf3f9e7f8a31f4e34c6</td>
#       <td>Java-разработчик</td>
#       <td>0.571429</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>746</th>
#       <td>53cc46b911ea4d74c60e4e166f4f1523</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.363636</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>747</th>
#       <td>54b11623b223600258755cc1ddcc72fc</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>748</th>
#       <td>881ddb6def47a4b02f66437139dab88d</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>749</th>
#       <td>b019bc51a3c84c368d0ace8948b576ab</td>
#       <td>JavaScript с нуля</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>750</th>
#       <td>182c269b61f0b3c322586e44525f1a2d</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>db870387155e0b795c8c85e91d377cbc</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>752</th>
#       <td>96d36c0265d0233145db69f8751607ef</td>
#       <td>JavaScript с нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>753</th>
#       <td>a0fc1e9af0ac4e264eff4fc4c2565c93</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>754</th>
#       <td>3ca6fb896b9201b7374ee318a2c0f9f6</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>755</th>
#       <td>9cba4f8cc423e9d7f13cdd6adaa6724f</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>756</th>
#       <td>6dc52a2f42b4626a34035bd4732de045</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.888889</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>757</th>
#       <td>c4a80ef6a2caae448704d9bb4a751314</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>758</th>
#       <td>c684bf2bcfb6ca2775f9366217167331</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>759</th>
#       <td>7d729b3fc722a2af4bc3d56e464c59cc</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>0.000000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>760</th>
#       <td>812735cf09cb38e4530ca388b656057b</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.600000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>761</th>
#       <td>93a6cf1ded8b8c6fb47b88b7d7a0acd5</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.777778</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>762</th>
#       <td>b15de63e5ab54c4ab7d70e21761ad337</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.600000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>763</th>
#       <td>7841c5734c68dfec83aa9c43ed2addce</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>764</th>
#       <td>0c1e1a9155822ddcb938af2d5174ab68</td>
#       <td>Веб-разработчик</td>
#       <td>0.562500</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>765</th>
#       <td>0503da67fdf4223cc98a9820a4fdf139</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>766</th>
#       <td>2a972412475b77e31599e678e48e5cac</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>767</th>
#       <td>4455457eb8b3d3a09e40a5af4004cddb</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>768</th>
#       <td>85ef138d58d632de3c2992a608100178</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>769</th>
#       <td>d18a06eda9b5fb5186f4e5ee4e74e42b</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>770</th>
#       <td>8ae0c72ac6838720fb9a5955a9e8f546</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>771</th>
#       <td>906659b8cd53f4820fc1a53801ee4072</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>772</th>
#       <td>b1e8f6195e2252318d51d66e8ae2b961</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>773</th>
#       <td>ba8f666aa0f25deaaca6c795dcee757d</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>774</th>
#       <td>8623f2248d4842c7b016a7a14af3a35c</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>775</th>
#       <td>ef3c8c2f27f576c69a97d1ef3cd4e66e</td>
#       <td>Java-разработчик</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>776</th>
#       <td>3c7a1c92847f9fd4d566ad2a4cccd5ac</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>0.666667</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>777</th>
#       <td>f079cede90927dfb37126799060a89f0</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>778</th>
#       <td>06114e0d623d6eb6e92d10d84ff8b3a3</td>
#       <td>Java-разработчик</td>
#       <td>0.000000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>779</th>
#       <td>0ff1bf250ba71faf0c47d7f2ec76fb1a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>780</th>
#       <td>da32b74b91c309d7cf8fee0d738310b4</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>781</th>
#       <td>3f87a7c6822d94a91fdf2cc74e12cd6a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>782</th>
#       <td>ec6edf79da928125eeeeeb6ab9674572</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>783</th>
#       <td>c361a66ad2d1f1c1ed8bd853f8f04815</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.600000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>784</th>
#       <td>012adf13237eaa7be1b7319ac94bbc3f</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.833333</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>785</th>
#       <td>c7aa81f54116320fa3ab77fd3afe531b</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>786</th>
#       <td>bccde8ede08608f366885fc18ff610b6</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.857143</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>787</th>
#       <td>d3f555050b43db3c2348b3e1d8177751</td>
#       <td>Excel Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>788</th>
#       <td>d6f61e69d12f2e6e14fb6fcb1a292251</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>789</th>
#       <td>7ccec21f4b83ce065bf45a9a98e06588</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>790</th>
#       <td>dbad5017e9ea95aee4f80b3f3b507dea</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>791</th>
#       <td>0aa309f5f5bb0a56017c7bfcd0cefbc8</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>792</th>
#       <td>9dcbbd4961a503935a70d608fb36e28a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>793</th>
#       <td>2f805d2bb8ee80538c5f558a28898d1c</td>
#       <td>UX-дизайн</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>794</th>
#       <td>7e53fd6199093b0137a99419c7bf8f6b</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>0.000000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>795</th>
#       <td>d546b8d5008365a5f297e9a34e4f4b24</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.166667</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>796</th>
#       <td>b51f36c5dc4f4910b6817b3c0a020187</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>797</th>
#       <td>3859037ee59294b079ad8b841a497063</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>798</th>
#       <td>09ecd4840be505bac40b878a47e59b21</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>799</th>
#       <td>b97234859e54450f474a867cca3a5b2c</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>800</th>
#       <td>4bda172c41ec483dbfd39207dbd0e7bb</td>
#       <td>Веб-разработчик</td>
#       <td>0.625000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>801</th>
#       <td>a27404b14996ff7cef982ad32dd7721e</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>802</th>
#       <td>eeafc8b360479f97930501d9c0505413</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>803</th>
#       <td>6de1c7fcdad253e9c189f7631fe48c91</td>
#       <td>Java-разработчик</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>804</th>
#       <td>67154f790e86bd6c99cb5603117ff84d</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.687500</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>805</th>
#       <td>8f1146a009fa3853f9cbd075456f8664</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>806</th>
#       <td>10f82f999d0390abf92affd248efef29</td>
#       <td>Руководитель digital-проектов</td>
#       <td>0.333333</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>807</th>
#       <td>e26054e71eb969830914e3fb614af1ce</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>808</th>
#       <td>b6ccc5b2224bf5efd9097779edda2c21</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>809</th>
#       <td>b9cffc6eef93a7f911644b06e51be367</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.923077</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>810</th>
#       <td>e6e847a1f74f1a6a22cf38b59cee234b</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>811</th>
#       <td>30e31bb39b960e5596f946a453a7c1fc</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>812</th>
#       <td>a4574c3fd47397c692125f1ff043bc2c</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>813</th>
#       <td>db109a1d5cfda250054ab6e08ee80962</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>814</th>
#       <td>8d6b05df355d03aa6fd08a180ab8e1ce</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>815</th>
#       <td>699df3d6952a9fcc759dbe403fbb17b0</td>
#       <td>UX-дизайн</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>816</th>
#       <td>4077fec12242c26354e117f719e0f977</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>817</th>
#       <td>28fa21e9d0ef9bf6d873351572587683</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>818</th>
#       <td>51e7d3b86e93be38fbe6a805227c12c8</td>
#       <td>JavaScript с нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>819</th>
#       <td>6d00ba87916de6bbba0fdf942c79c953</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.166667</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>820</th>
#       <td>2b806ff3f79894abe1a387e0a0868e1f</td>
#       <td>UX-дизайн</td>
#       <td>1.833333</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>821</th>
#       <td>ffb687843c211c094de229b2fb9bbfbe</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>822</th>
#       <td>e88c34ef98fc397f26cd6af66903fe8f</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>823</th>
#       <td>ee082014330bd73b4fb7f52e2fcd3add</td>
#       <td>Excel Базовый</td>
#       <td>0.666667</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>824</th>
#       <td>97f3a8a2c90fe0f11bc105a71afc6cec</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>825</th>
#       <td>5affef1e1f43ac36487bfab3e237de05</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>826</th>
#       <td>ac925819964c89145b33a2be49a69209</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>827</th>
#       <td>3d94620555817a287805be7a2f8802b4</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>828</th>
#       <td>f7e11cda9773c06fdbac8ecb4061d04a</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>829</th>
#       <td>3bb56182b33b4ddfc4385f776ea950df</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>830</th>
#       <td>ba0e1acde4fe47288fea9046fcf316f6</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>831</th>
#       <td>a5c68ece307a506013e799c370911c84</td>
#       <td>UX-дизайн</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>832</th>
#       <td>d640b92f0af1abc441df62ef375d5817</td>
#       <td>Руководитель digital-проектов</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>833</th>
#       <td>1e372c518fa643a6cc6494e6a7430843</td>
#       <td>UX-дизайн</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>834</th>
#       <td>5894df12c7974a6c8b9aeda61dc24dae</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>835</th>
#       <td>62f832ae541a69f31fac01c01ed6c965</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>836</th>
#       <td>f8b67556f87e1204a53ca371b2489552</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>837</th>
#       <td>3b2033f8c8d7c4912a80cfd3365e1b68</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>838</th>
#       <td>1633763f00304f8a18eddbbf366a350e</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>839</th>
#       <td>cde444eabc1e5d4a3ae889f62050acec</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>840</th>
#       <td>e43192e425d31e916f3875ad3a934887</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>841</th>
#       <td>71b235a59b93548f8af3943865d40946</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>842</th>
#       <td>6a8c3ae6677b5c45adc2a9885f21f724</td>
#       <td>Excel Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>843</th>
#       <td>c8c3a9756b856906b3cf4b841134db73</td>
#       <td>Java-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>844</th>
#       <td>f13546ec6f482cf2fac4fca27827d888</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>845</th>
#       <td>ee3da89ef20a16e1997002ae23508225</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>846</th>
#       <td>f9736914c7e54e1a2fca48751d77aecb</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>847</th>
#       <td>135e13c2c13d782f1e407bfe1daa5b27</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.857143</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>848</th>
#       <td>6cebc3ef9e93b24ebce4c450b97c37ba</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>849</th>
#       <td>75fc34e11bc3e682b747bd008102b3f5</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>850</th>
#       <td>38566c53745f653ab393887b197c4715</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th
</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>892</th>
#       <td>08f7050d158e5e6d3f3ea0e848a3cea6</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>0d5f2d6e7e186ded9d1a9382033937a6</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.933333</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>894</th>
#       <td>964d20017040d2b0245dd76436c677c7</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>895</th>
#       <td>7aca26484ed6e7d8bcbc86ad898c35fd</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.833333</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>896</th>
#       <td>04256d8a2318fa9f90918f4b3e310473</td>
#       <td>Excel Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>897</th>
#       <td>000333b6aa5706c53f4d2ec24c7a128d</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>898</th>
#       <td>8074b5bc08e12b8503ba9f54a6ad29a6</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>899</th>
#       <td>b291f3908fee28436c95f8bb8c1fe9d8</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>900</th>
#       <td>1d50e201cfa61e4dff3adce0b121bdd7</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>901</th>
#       <td>7e76d3a1f061d218103320cc867c21cd</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>902</th>
#       <td>80d0c1ffbc254b04c38d9b24264e1785</td>
#       <td>Java-разработчик</td>
#       <td>1.375000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>903</th>
#       <td>966307dacf98215896ac4dada3a6f242</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>904</th>
#       <td>3f533726c4a45809a382f866896d0500</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>905</th>
#       <td>d88ef3651e8a1f17030aa23b8a1a7eab</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>906</th>
#       <td>a068094c8fcb1d03817d50eb6a01e4bb</td>
#       <td>Java-разработчик</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>907</th>
#       <td>9ed0ba403412e273ef161c0709d97c9d</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>908</th>
#       <td>fbd765ab8386b76755457b0c1b293b2d</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>909</th>
#       <td>feb05780b6dd98669a052be13c5c9c24</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>910</th>
#       <td>e885403b947af367b5937a1e73ba4972</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>911</th>
#       <td>ae83d5068fca1c60237dde9fabc80435</td>
#       <td>Excel Базовый</td>
#       <td>1.285714</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>912</th>
#       <td>db9016d42da35ccfe463109e63a858d2</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>913</th>
#       <td>f5d44966a50e702b502c76f3918b43f2</td>
#       <td>Java-разработчик</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>914</th>
#       <td>fe95bd1e7a328c7de6970b4a4e7bc370</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>915</th>
#       <td>38b2fb2b880a09e3601b30929031192f</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>916</th>
#       <td>eecf6d08c8961aa0d3eb9afc51945698</td>
#       <td>UX-дизайн</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>917</th>
#       <td>3190478b95e52b8ca83ea3c7d50278b7</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>918</th>
#       <td>28f525baf1715ecbceb9c7187a362b2f</td>
#       <td>Java-разработчик</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>919</th>
#       <td>0898bc700b35fe976c0fc32d4cb8b687</td>
#       <td>UX-дизайн</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>920</th>
#       <td>ece2e889777e1eb3dba6d77ff5b866b7</td>
#       <td>UX-дизайн</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>921</th>
#       <td>ab8de33f423f3c63ff2b50a477ce7168</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>922</th>
#       <td>20165d40da3f747e99af33ff20c7fdb1</td>
#       <td>Java-разработчик</td>
#       <td>1.636364</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>923</th>
#       <td>d1f3aab20e2c3cede53ed98119b57e4c</td>
#       <td>Java-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>924</th>
#       <td>fdc69a1ea269f4ef87bf48148f4ac1de</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>925</th>
#       <td>af9e188f17c2572b6fe62a9fa2636ecf</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>926</th>
#       <td>8101a2515cb58f3b273af307c2fc251e</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>927</th>
#       <td>e06e5a488441f994e0ac5e0d4e5e61e2</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>928</th>
#       <td>b501895b350bf9bb8e7d224b5811cdbc</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>929</th>
#       <td>d02881ac3cea4c87d17b5ef16bbaea8a</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>930</th>
#       <td>d95308a591c61575c63b528abdadcf2c</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>931</th>
#       <td>3a7782e3dc3607bde48d39a6373d7e60</td>
#       <td>Java-разработчик</td>
#       <td>1.909091</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>932</th>
#       <td>955ace6718a9acb18dd8170e0f2ef3bf</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>933</th>
#       <td>7d45911edd9be0b8fb193022f412f8f9</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>934</th>
#       <td>12021fb2fa6ed23ac6e16973c5c95f3e</td>
#       <td>Java-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>935</th>
#       <td>e5a091d85e69ee12f09b562f1af0c074</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>936</th>
#       <td>d13bb03db7158d33698cc830b0801a2d</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>937</th>
#       <td>0eb1bf7ffc51e69420a8bbc69205aa0a</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>938</th>
#       <td>32537ad79a9c888547d120d53c3b60bd</td>
#       <td>UX-дизайн</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>939</th>
#       <td>d7d41b85a6d6774bb80369a8a8f4f7ae</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>940</th>
#       <td>cd950b375b19c6eaddc6c0c40de0e609</td>
#       <td>Java-разработчик</td>
#       <td>1.571429</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>941</th>
#       <td>e3dce9e9047268fa550fd1b2bec731e8</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>942</th>
#       <td>7eab35b5b2d2c1b3d55b6b05f1a7c485</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>943</th>
#       <td>645629052b77b1f8da2265cd0b80fd9e</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>944</th>
#       <td>9f37ba8a02395d0b340f62ddee397e83</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>945</th>
#       <td>1c1d5b607c58bab78fcd3e16f191c7f7</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>946</th>
#       <td>d78e7fa97cf335e06ae10042f338c005</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>947</th>
#       <td>20b765ca8106ce820bd1e130e2aa79ce</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>948</th>
#       <td>f86f6b8d34e9eb88c6ccf5100da46a13</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>949</th>
#       <td>194f135a97b56264ea18adde51c6fa78</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>950</th>
#       <td>768c2987a744c51ce64a5993a2a94eaf</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>951</th>
#       <td>6bdba555d353c560ad484399151e22d3</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>952</th>
#       <td>ec7f507ff45af0f93994baec76bcdf6e</td>
#       <td>JavaScript с нуля</td>
#       <td>1.250000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>953</th>
#       <td>22b73c2442ed4a897aeec55b77995c5c</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.714286</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>954</th>
#       <td>42bd41bdbaa3faf1ba661596416f5e90</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>955</th>
#       <td>2e79de08f0afb030a8e429ee9bcd9109</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>0.666667</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>956</th>
#       <td>ef7e398061c4a8d62bcf6682abd73519</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>957</th>
#       <td>1150bdf8297efb5b409f4ca634c8fc8b</td>
#       <td>Excel Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>958</th>
#       <td>68e99df14b9547bd723ef86c056b5302</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>959</th>
#       <td>c5fdd76a235e7f3092f7eaa94d73f68c</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>960</th>
#       <td>c67484997efff9df7dd81264c9428f3a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.375000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>961</th>
#       <td>e6079cd9d972683bf37a4fee6ae89c54</td>
#       <td>Java-разработчик</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>962</th>
#       <td>2c849c9ec86bbe132550211831eaf9ad</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>963</th>
#       <td>fde2920308cb1159218ffa58a9f4e393</td>
#       <td>Java-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>964</th>
#       <td>b3e486ce9c9d328a30e4cf516b9a85a6</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>965</th>
#       <td>122d38ca1292b13d9b5f39eb5467cfbb</td>
#       <td>JavaScript с нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>966</th>
#       <td>bbd15f14bdff1c1f6e8cec2fefe24180</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>967</th>
#       <td>e086e3fc380231a21e17a4042c214c3d</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>968</th>
#       <td>d0f1dd3cdf56f69acdd99f7240944e58</td>
#       <td>UX-дизайн</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>969</th>
#       <td>627127bf90a2a86c10dc3acf2f5066ff</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>970</th>
#       <td>76db3673070466a5ab95e280db9595e0</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.888889</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>971</th>
#       <td>7ec74b966dae46c0a3cb50b8abd1c6d3</td>
#       <td>Руководитель digital-проектов</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>972</th>
#       <td>3ed9fa3aa33148a83af9a9d5f283d031</td>
#       <td>Java-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>973</th>
#       <td>de563951cd17d8bcddd4cd55fc4a34c9</td>
#       <td>Java-разработчик</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>974</th>
#       <td>f780ff6d03a03f378e298eb2c515b83d</td>
#       <td>UX-дизайн</td>
#       <td>1.714286</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>975</th>
#       <td>cc687dd2104e1e07dbc701b0e043fcfc</td>
#       <td>JavaScript с нуля</td>
#       <td>1.714286</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>976</th>
#       <td>f9af6e812402da5ed461d9c1361aee56</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>977</th>
#       <td>eaf0564e6ca7a36ca0e0965107e4ebe5</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>978</th>
#       <td>0dc30818b80a41a16114025bd68c9af3</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.833333</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>979</th>
#       <td>5c3f87ae7194ad275544fc37dc1121fc</td>
#       <td>PHP-разработчик с 0 до PRO. Часть 1</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>980</th>
#       <td>7068fa47f4b19e7fd18c2e450641f5d2</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>981</th>
#       <td>d206e514e8287d0111e9b300cbd845a0</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>982</th>
#       <td>fe52fb46f53bc61cb8f0d46ba52ccfc2</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>983</th>
#       <td>5f2d4dadc39fbe1dacb2cdb64f1e2c8d</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>984</th>
#       <td>ce64d8a90b633f2ec027504b153f81ca</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>b0b8fffd7ba66c95d4840d01c0df3a35</td>
#       <td>UX-дизайн</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>986</th>
#       <td>f00e8dd39cf2ff47f10148c66784ca4d</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>987</th>
#       <td>cc30094fee78af053ce415a03639f724</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>988</th>
#       <td>6f8fe8b50b9341bb1e3b4e0fcaeaa731</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>989</th>
#       <td>2d3162e1c088b054dd6682cc4934c354</td>
#       <td>JavaScript с нуля</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>990</th>
#       <td>0413c20b56848a423475c7ddaeeee676</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>991</th>
#       <td>ede0d6645e98cc17ec6adde44241587d</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>992</th>
#       <td>d1d1000316314b025c70d0642db03a40</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>993</th>
#       <td>77ac959bc9e668d106a5271d5f71cbe8</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>994</th>
#       <td>7e1a1fde221b26c72a488cbc64912c26</td>
#       <td>UX-дизайн</td>
#       <td>1.857143</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>995</th>
#       <td>450877774e677a004b16d2c6a9a4c5d9</td>
#       <td>Excel Базовый</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>996</th>
#       <td>6296a047c05bdd68946f9df7a9ef3c4d</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.400000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>997</th>
#       <td>fcc48626c9729b830e90c77c7260dbd0</td>
#       <td>JavaScript с нуля</td>
#       <td>1.857143</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>998</th>
#       <td>9261c70a5d1224a47eee623bc9759b8d</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>999</th>
#       <td>02053c816359dad8566d6425be5e7d36</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1000</th>
#       <td>1c6e86934e3c0eabece45d2440b5218a</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1001</th>
#       <td>f0bd56803d889fb13081e905e0bace46</td>
#       <td>Веб-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1002</th>
#       <td>b38281ab93c71eeba79b982cdbcd9dee</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1003</th>
#       <td>21471e3c1bcd67aadc6359209e3f2d32</td>
#       <td>Веб-разработчик</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1004</th>
#       <td>f18989d4fded8ea70b380d79ff870c7d</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1005</th>
#       <td>9f9d6049d99134318a028cb0c4c78f8a</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.875000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1006</th>
#       <td>ca01a7d4712c0cfcf3bcee72bd144ee9</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.647059</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1007</th>
#       <td>f7983f40829fa687b78fe9c8936b16f5</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.428571</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1008</th>
#       <td>39aac7dbe6d34df7d30170b0afd58abf</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1009</th>
#       <td>bdf2b20dcbe5abf59254d509a1a39ed4</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1010</th>
#       <td>7da31ed1655ba6a848788b6728d41a54</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.625000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1011</th>
#       <td>9065625010210cec8c64ed0ad12ef0e6</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.923077</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1012</th>
#       <td>2df2de71e3174b92e4ec4b998a5e710e</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1013</th>
#       <td>2d5c252c9f7d01f4f97b820e2558f575</td>
#       <td>Java-разработчик</td>
#       <td>1.833333</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1014</th>
#       <td>0526453e2693bf0519e60bf2f0e1f6fb</td>
#       <td>JavaScript с нуля</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1015</th>
#       <td>f9576b8a00dd55014c56ecb4a8160eee</td>
#       <td>Java-разработчик</td>
#       <td>1.428571</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1016</th>
#       <td>29ea27809a66f6ce034f906d1c3f89e7</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>
td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>1441</th>
#       <td>bf3364fc89f5cbed01d50e12ed5a6f0c</td>
#       <td>UX-дизайн</td>
#       <td>0.200000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>1442</th>
#       <td>798541a5e99a79e3a89429583cf105ec</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1443</th>
#       <td>b6cc0a74b4723f0c6731934f7178c67d</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1444</th>
#       <td>3750ef85c5633e687d5645a759c82e31</td>
#       <td>Анимация интерфейсов</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1445</th>
#       <td>596670845b3b6fe0462e81075ba433d5</td>
#       <td>Java-разработчик c нуля</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1446</th>
#       <td>47d4cb9250c0f24546fc34213f0f44de</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1447</th>
#       <td>82c7438adaad49087c9b301cd6c72737</td>
#       <td>Excel Базовый</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1448</th>
#       <td>38f272b6dfd0770a6671b4e8b264a894</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1449</th>
#       <td>c89927c34528144d489fd46635020849</td>
#       <td>Excel Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1450</th>
#       <td>4d15969dacebf187e5cdf27b426125ec</td>
#       <td>Руководитель digital-проектов</td>
#       <td>0.500000</td>
#       <td>lags a lot</td>
#     </tr>
#     <tr>
#       <th>1451</th>
#       <td>e5cc9bc6debb4f15483c429f3deea8c8</td>
#       <td>Веб-вёрстка для начинающих 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1452</th>
#       <td>9eaf02ac9db91738a435305df30e9eb6</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1453</th>
#       <td>c0c9be188c29a1f97b7e723b219ecd52</td>
#       <td>UX-дизайн</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1454</th>
#       <td>c1df5cd242684849d15807a648c25635</td>
#       <td>JavaScript с нуля</td>
#       <td>1.800000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1455</th>
#       <td>00386b771938472b2df62108f5985c1e</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1456</th>
#       <td>96a4ad579f1f4f11012e4344ab88441c</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.200000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1457</th>
#       <td>afb09a4f2c252c4541cfa62deba3ae8d</td>
#       <td>Java-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1458</th>
#       <td>4430aac4c96cbd54453328e6e77eabcf</td>
#       <td>JavaScript с нуля</td>
#       <td>1.818182</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1459</th>
#       <td>4a67701e25bc94b6a7e0f687b1c2eaa5</td>
#       <td>UX-дизайн</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1460</th>
#       <td>9828a1fd36a680ee8e8528f141b2a5cf</td>
#       <td>Веб-дизайн с нуля 2.0</td>
#       <td>1.333333</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1461</th>
#       <td>670c8c699845c8e3c64bff76245d0b40</td>
#       <td>Веб-дизайн PRO 2.0</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1462</th>
#       <td>b3ded9ebb051a593c8820227655e53d3</td>
#       <td>SMM-маркетолог от А до Я</td>
#       <td>1.500000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1463</th>
#       <td>a15cccb5741cf617748cd23d74899c31</td>
#       <td>Веб-разработчик</td>
#       <td>1.666667</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1464</th>
#       <td>19e67ac8e87f2fa0c5c11ee7c99d865f</td>
#       <td>Веб-дизайн Базовый</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1465</th>
#       <td>f6328776cfa6f9aa41cc539843bee767</td>
#       <td>JavaScript с нуля</td>
#       <td>1.750000</td>
#       <td>lags a bit</td>
#     </tr>
#     <tr>
#       <th>1466</th>
#       <td>d93df7668d6358630d8a76ef334d8032</td>
#       <td>Интернет-маркетолог от Ingate</td>
#       <td>1.000000</td>
#       <td>lags</td>
#     </tr>
#     <tr>
#       <th>1467</th>
#       <td>f8687c4709f0eb322b00ac3ab7ff0150</td>
#       <td>Excel Базовый</td>
#       <td>1.857143</td>
#       <td>lags a bit</td>
#     </tr>
#   </tbody>
# </table>
